# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import PySpice.Logging.Logging as Logging
logger = Logging.setup_logging()
from PySpice.Spice.Netlist import SubCircuitFactory
from PySpice.Doc.ExampleTools import find_libraries
from PySpice.Spice.Netlist import Circuit,SubCircuit
from PySpice.Spice.Library import SpiceLibrary
from PySpice.Unit import *
from PySpice.Probe.Plot import plot
from PySpice.Logging.Logging import setup_logging
from multiprocessing import Pool
from PySpice.Spice.NgSpice.Shared import NgSpiceShared
import random
setup_logging()

libraries_path = find_libraries()
spice_library = SpiceLibrary(libraries_path)

# %%
def generate_mn_range(M_start, M_end, N_start, N_end):
    special_mn = []
    for m in range(M_start, M_end+1):
        for n in range(N_start, N_end+1):
            special_mn.append((m, n))
    return special_mn

# %%
M = 364
N = 91
w = 0.0025
l = 0.0025

# %%
def create_tandem_array(M, N, special_mn):
    circuit = Circuit('Perovskite/Silicon Tandem Equivalent Circuit')
    
    circuit.model('D1_top', 'D', IS = 8.8e-23*(w*l), N =1)
    circuit.model('D2_top', 'D', IS = 2.62e-13*(w*l), N =2)
    circuit.model('D1_bot', 'D', IS=1.3339e-14*(w*l), N =1)
    circuit.model('D2_bot', 'D', IS=6.5674e-19*(w*l), N =2)
    circuit.V('1', 'input', circuit.gnd, 0@u_V)

    for m in range(M):
        for n in range(N):
            name_prefix = f"{m:03d}{n:03d}"
            is_special = (m, n) in special_mn
            print(f"Processing m={m}, n={n}, is_special={is_special}")
            
            # Metal Sheet Resistance
            if m == 0:
                circuit.R(f'Metal_sheet_input{n:03d}', 'input', f'q{m:03d}{n:03d}', 2.13*l/w@u_mOhm)
            if ( m == 1 and 0 < n < 91) or (m > 1 and  n == 45):
                circuit.R(f'Metal_sheet_v{m:03d}{n:03d}', f'q{m-1:03d}{n:03d}', f'q{m:03d}{n:03d}', 2.13*l/w@u_mOhm)
                circuit.R(f'Metal_sheet_h{m:03d}{n:03d}', f'q{m:03d}{n-1:03d}', f'q{m:03d}{n:03d}', 2.13*w/l@u_mOhm)
                circuit.R(f'c_metal_{name_prefix}', f'q{m:03d}{n:03d}', f'a{m:03d}{n:03d}', 5/(w*l)@u_mOhm)            
            
                
            # ITO Sheet Resistance
            
            if m > 0:
                circuit.R(f'ITO_sheet_v{m:03d}{n:03d}', f'a{m-1:03d}{n:03d}', f'a{m:03d}{n:03d}', 55*l/w@u_Ohm)
            if n > 0:
                circuit.R(f'ITO_sheet_h{m:03d}{n:03d}', f'a{m:03d}{n-1:03d}', f'a{m:03d}{n:03d}', 55*w/l@u_Ohm)

            # RJ Sheet Resistance
            if m > 0:
                circuit.R(f'RJ_sheet_v{m:03d}{n:03d}', f'd{m-1:03d}{n:02d}', f'd{m:03d}{n:03d}', 200*l/w@u_Ohm)
            if n > 0:
                circuit.R(f'RJ_sheet_h{m:03d}{n:03d}', f'd{m:03d}{n-1:03d}', f'd{m:03d}{n:03d}', 200*w/l@u_Ohm)

            # Top Cell
            if is_special:
                circuit.R(f's_top_{name_prefix}', f'a{m:03d}{n:03d}', f'b{m:03d}{n:03d}', 5.55/(w*l)@u_kOhm)
            else:
                circuit.R(f's_top_{name_prefix}', f'a{m:03d}{n:03d}', f'b{m:03d}{n:03d}', 2/(w*l)@u_Ohm)
            circuit.D(f'1_top_{name_prefix}', f'b{m:03d}{n:03d}', f'c{m:03d}{n:03d}', model='D1_top')
            circuit.D(f'2_top_{name_prefix}', f'b{m:03d}{n:03d}', f'c{m:03d}{n:03d}', model='D2_top')
            circuit.R(f'sh_top_{name_prefix}', f'b{m:03d}{n:03d}', f'c{m:03d}{n:03d}', 5.55/(w*l)@u_kOhm)
                
            if (m < 2 and n < 91) or (m > 1 and  n == 45):
                circuit.I(f'ph_top_{name_prefix}', f'c{m:03d}{n:03d}', f'b{m:03d}{n:03d}', 0*(w*l)@u_mA)
            else:
                circuit.I(f'ph_top_{name_prefix}', f'c{m:03d}{n:03d}', f'b{m:03d}{n:03d}', 19.65*(w*l)@u_mA)

            # Connection
            circuit.R(f'c_top_{name_prefix}', f'c{m:03d}{n:03d}', f'd{m:03d}{n:03d}', 0/(w*l)@u_mOhm)
            circuit.R(f'c_bot_{name_prefix}', f'd{m:03d}{n:03d}', f'e{m:03d}{n:03d}', 0/(w*l)@u_mOhm)

            # Bottom Cell
            circuit.R(f's_bot_{name_prefix}', f'e{m:03d}{n:03d}', f'f{m:03d}{n:03d}', 0.2/(w*l)@u_Ohm)
            circuit.D(f'1_bot_{name_prefix}', f'f{m:03d}{n:03d}', circuit.gnd, model='D1_bot')
            circuit.D(f'2_bot_{name_prefix}', f'f{m:03d}{n:03d}', circuit.gnd, model='D2_bot')
            circuit.R(f'sh_bot_{name_prefix}', f'f{m:03d}{n:03d}', circuit.gnd, 12/(w*l)@u_kOhm)
            if (m < 2 and n < 91) or (m > 1 and  n == 45):
                circuit.I(f'ph_bot_{name_prefix}', circuit.gnd, f'f{m:03d}{n:03d}', 0*(w*l)@u_mA)
            else:
                circuit.I(f'ph_bot_{name_prefix}', circuit.gnd, f'f{m:03d}{n:03d}', 19.65*(w*l)@u_mA)

    return circuit

# %%
M_start = 335
M_end = 349
N_start = 71
N_end = 85
special_mn = generate_mn_range(M_start, M_end, N_start, N_end)
circuit = create_tandem_array(M, N, special_mn)
# Out:
# Processing m=0, n=0, is_special=False
# Processing m=0, n=1, is_special=False
# Processing m=0, n=2, is_special=False
# Processing m=0, n=3, is_special=False
# Processing m=0, n=4, is_special=False
# Processing m=0, n=5, is_special=False
# Processing m=0, n=6, is_special=False
# Processing m=0, n=7, is_special=False
# Processing m=0, n=8, is_special=False
# Processing m=0, n=9, is_special=False
# Processing m=0, n=10, is_special=False
# Processing m=0, n=11, is_special=False
# Processing m=0, n=12, is_special=False
# Processing m=0, n=13, is_special=False
# Processing m=0, n=14, is_special=False
# Processing m=0, n=15, is_special=False
# Processing m=0, n=16, is_special=False
# Processing m=0, n=17, is_special=False
# Processing m=0, n=18, is_special=False
# Processing m=0, n=19, is_special=False
# Processing m=0, n=20, is_special=False
# Processing m=0, n=21, is_special=False
# Processing m=0, n=22, is_special=False
# Processing m=0, n=23, is_special=False
# Processing m=0, n=24, is_special=False
# Processing m=0, n=25, is_special=False
# Processing m=0, n=26, is_special=False
# Processing m=0, n=27, is_special=False
# Processing m=0, n=28, is_special=False
# Processing m=0, n=29, is_special=False
# Processing m=0, n=30, is_special=False
# Processing m=0, n=31, is_special=False
# Processing m=0, n=32, is_special=False
# Processing m=0, n=33, is_special=False
# Processing m=0, n=34, is_special=False
# Processing m=0, n=35, is_special=False
# Processing m=0, n=36, is_special=False
# Processing m=0, n=37, is_special=False
# Processing m=0, n=38, is_special=False
# Processing m=0, n=39, is_special=False
# Processing m=0, n=40, is_special=False
# Processing m=0, n=41, is_special=False
# Processing m=0, n=42, is_special=False
# Processing m=0, n=43, is_special=False
# Processing m=0, n=44, is_special=False
# Processing m=0, n=45, is_special=False
# Processing m=0, n=46, is_special=False
# Processing m=0, n=47, is_special=False
# Processing m=0, n=48, is_special=False
# Processing m=0, n=49, is_special=False
# Processing m=0, n=50, is_special=False
# Processing m=0, n=51, is_special=False
# Processing m=0, n=52, is_special=False
# Processing m=0, n=53, is_special=False
# Processing m=0, n=54, is_special=False
# Processing m=0, n=55, is_special=False
# Processing m=0, n=56, is_special=False
# Processing m=0, n=57, is_special=False
# Processing m=0, n=58, is_special=False
# Processing m=0, n=59, is_special=False
# Processing m=0, n=60, is_special=False
# Processing m=0, n=61, is_special=False
# Processing m=0, n=62, is_special=False
# Processing m=0, n=63, is_special=False
# Processing m=0, n=64, is_special=False
# Processing m=0, n=65, is_special=False
# Processing m=0, n=66, is_special=False
# Processing m=0, n=67, is_special=False
# Processing m=0, n=68, is_special=False
# Processing m=0, n=69, is_special=False
# Processing m=0, n=70, is_special=False
# Processing m=0, n=71, is_special=False
# Processing m=0, n=72, is_special=False
# Processing m=0, n=73, is_special=False
# Processing m=0, n=74, is_special=False
# Processing m=0, n=75, is_special=False
# Processing m=0, n=76, is_special=False
# Processing m=0, n=77, is_special=False
# Processing m=0, n=78, is_special=False
# Processing m=0, n=79, is_special=False
# Processing m=0, n=80, is_special=False
# Processing m=0, n=81, is_special=False
# Processing m=0, n=82, is_special=False
# Processing m=0, n=83, is_special=False
# Processing m=0, n=84, is_special=False
# Processing m=0, n=85, is_special=False
# Processing m=0, n=86, is_special=False
# Processing m=0, n=87, is_special=False
# Processing m=0, n=88, is_special=False
# Processing m=0, n=89, is_special=False
# Processing m=0, n=90, is_special=False
# Processing m=1, n=0, is_special=False
# Processing m=1, n=1, is_special=False
# Processing m=1, n=2, is_special=False
# Processing m=1, n=3, is_special=False
# Processing m=1, n=4, is_special=False
# Processing m=1, n=5, is_special=False
# Processing m=1, n=6, is_special=False
# Processing m=1, n=7, is_special=False
# Processing m=1, n=8, is_special=False
# Processing m=1, n=9, is_special=False
# Processing m=1, n=10, is_special=False
# Processing m=1, n=11, is_special=False
# Processing m=1, n=12, is_special=False
# Processing m=1, n=13, is_special=False
# Processing m=1, n=14, is_special=False
# Processing m=1, n=15, is_special=False
# Processing m=1, n=16, is_special=False
# Processing m=1, n=17, is_special=False
# Processing m=1, n=18, is_special=False
# Processing m=1, n=19, is_special=False
# Processing m=1, n=20, is_special=False
# Processing m=1, n=21, is_special=False
# Processing m=1, n=22, is_special=False
# Processing m=1, n=23, is_special=False
# Processing m=1, n=24, is_special=False
# Processing m=1, n=25, is_special=False
# Processing m=1, n=26, is_special=False
# Processing m=1, n=27, is_special=False
# Processing m=1, n=28, is_special=False
# Processing m=1, n=29, is_special=False
# Processing m=1, n=30, is_special=False
# Processing m=1, n=31, is_special=False
# Processing m=1, n=32, is_special=False
# Processing m=1, n=33, is_special=False
# Processing m=1, n=34, is_special=False
# Processing m=1, n=35, is_special=False
# Processing m=1, n=36, is_special=False
# Processing m=1, n=37, is_special=False
# Processing m=1, n=38, is_special=False
# Processing m=1, n=39, is_special=False
# Processing m=1, n=40, is_special=False
# Processing m=1, n=41, is_special=False
# Processing m=1, n=42, is_special=False
# Processing m=1, n=43, is_special=False
# Processing m=1, n=44, is_special=False
# Processing m=1, n=45, is_special=False
# Processing m=1, n=46, is_special=False
# Processing m=1, n=47, is_special=False
# Processing m=1, n=48, is_special=False
# Processing m=1, n=49, is_special=False
# Processing m=1, n=50, is_special=False
# Processing m=1, n=51, is_special=False
# Processing m=1, n=52, is_special=False
# Processing m=1, n=53, is_special=False
# Processing m=1, n=54, is_special=False
# Processing m=1, n=55, is_special=False
# Processing m=1, n=56, is_special=False
# Processing m=1, n=57, is_special=False
# Processing m=1, n=58, is_special=False
# Processing m=1, n=59, is_special=False
# Processing m=1, n=60, is_special=False
# Processing m=1, n=61, is_special=False
# Processing m=1, n=62, is_special=False
# Processing m=1, n=63, is_special=False
# Processing m=1, n=64, is_special=False
# Processing m=1, n=65, is_special=False
# Processing m=1, n=66, is_special=False
# Processing m=1, n=67, is_special=False
# Processing m=1, n=68, is_special=False
# Processing m=1, n=69, is_special=False
# Processing m=1, n=70, is_special=False
# Processing m=1, n=71, is_special=False
# Processing m=1, n=72, is_special=False
# Processing m=1, n=73, is_special=False
# Processing m=1, n=74, is_special=False
# Processing m=1, n=75, is_special=False
# Processing m=1, n=76, is_special=False
# Processing m=1, n=77, is_special=False
# Processing m=1, n=78, is_special=False
# Processing m=1, n=79, is_special=False
# Processing m=1, n=80, is_special=False
# Processing m=1, n=81, is_special=False
# Processing m=1, n=82, is_special=False
# Processing m=1, n=83, is_special=False
# Processing m=1, n=84, is_special=False
# Processing m=1, n=85, is_special=False
# Processing m=1, n=86, is_special=False
# Processing m=1, n=87, is_special=False
# Processing m=1, n=88, is_special=False
# Processing m=1, n=89, is_special=False
# Processing m=1, n=90, is_special=False
# Processing m=2, n=0, is_special=False
# Processing m=2, n=1, is_special=False
# Processing m=2, n=2, is_special=False
# Processing m=2, n=3, is_special=False
# Processing m=2, n=4, is_special=False
# Processing m=2, n=5, is_special=False
# Processing m=2, n=6, is_special=False
# Processing m=2, n=7, is_special=False
# Processing m=2, n=8, is_special=False
# Processing m=2, n=9, is_special=False
# Processing m=2, n=10, is_special=False
# Processing m=2, n=11, is_special=False
# Processing m=2, n=12, is_special=False
# Processing m=2, n=13, is_special=False
# Processing m=2, n=14, is_special=False
# Processing m=2, n=15, is_special=False
# Processing m=2, n=16, is_special=False
# Processing m=2, n=17, is_special=False
# Processing m=2, n=18, is_special=False
# Processing m=2, n=19, is_special=False
# Processing m=2, n=20, is_special=False
# Processing m=2, n=21, is_special=False
# Processing m=2, n=22, is_special=False
# Processing m=2, n=23, is_special=False
# Processing m=2, n=24, is_special=False
# Processing m=2, n=25, is_special=False
# Processing m=2, n=26, is_special=False
# Processing m=2, n=27, is_special=False
# Processing m=2, n=28, is_special=False
# Processing m=2, n=29, is_special=False
# Processing m=2, n=30, is_special=False
# Processing m=2, n=31, is_special=False
# Processing m=2, n=32, is_special=False
# Processing m=2, n=33, is_special=False
# Processing m=2, n=34, is_special=False
# Processing m=2, n=35, is_special=False
# Processing m=2, n=36, is_special=False
# Processing m=2, n=37, is_special=False
# Processing m=2, n=38, is_special=False
# Processing m=2, n=39, is_special=False
# Processing m=2, n=40, is_special=False
# Processing m=2, n=41, is_special=False
# Processing m=2, n=42, is_special=False
# Processing m=2, n=43, is_special=False
# Processing m=2, n=44, is_special=False
# Processing m=2, n=45, is_special=False
# Processing m=2, n=46, is_special=False
# Processing m=2, n=47, is_special=False
# Processing m=2, n=48, is_special=False
# Processing m=2, n=49, is_special=False
# Processing m=2, n=50, is_special=False
# Processing m=2, n=51, is_special=False
# Processing m=2, n=52, is_special=False
# Processing m=2, n=53, is_special=False
# Processing m=2, n=54, is_special=False
# Processing m=2, n=55, is_special=False
# Processing m=2, n=56, is_special=False
# Processing m=2, n=57, is_special=False
# Processing m=2, n=58, is_special=False
# Processing m=2, n=59, is_special=False
# Processing m=2, n=60, is_special=False
# Processing m=2, n=61, is_special=False
# Processing m=2, n=62, is_special=False
# Processing m=2, n=63, is_special=False
# Processing m=2, n=64, is_special=False
# Processing m=2, n=65, is_special=False
# Processing m=2, n=66, is_special=False
# Processing m=2, n=67, is_special=False
# Processing m=2, n=68, is_special=False
# Processing m=2, n=69, is_special=False
# Processing m=2, n=70, is_special=False
# Processing m=2, n=71, is_special=False
# Processing m=2, n=72, is_special=False
# Processing m=2, n=73, is_special=False
# Processing m=2, n=74, is_special=False
# Processing m=2, n=75, is_special=False
# Processing m=2, n=76, is_special=False
# Processing m=2, n=77, is_special=False
# Processing m=2, n=78, is_special=False
# Processing m=2, n=79, is_special=False
# Processing m=2, n=80, is_special=False
# Processing m=2, n=81, is_special=False
# Processing m=2, n=82, is_special=False
# Processing m=2, n=83, is_special=False
# Processing m=2, n=84, is_special=False
# Processing m=2, n=85, is_special=False
# Processing m=2, n=86, is_special=False
# Processing m=2, n=87, is_special=False
# Processing m=2, n=88, is_special=False
# Processing m=2, n=89, is_special=False
# Processing m=2, n=90, is_special=False
# Processing m=3, n=0, is_special=False
# Processing m=3, n=1, is_special=False
# Processing m=3, n=2, is_special=False
# Processing m=3, n=3, is_special=False
# Processing m=3, n=4, is_special=False
# Processing m=3, n=5, is_special=False
# Processing m=3, n=6, is_special=False
# Processing m=3, n=7, is_special=False
# Processing m=3, n=8, is_special=False
# Processing m=3, n=9, is_special=False
# Processing m=3, n=10, is_special=False
# Processing m=3, n=11, is_special=False
# Processing m=3, n=12, is_special=False
# Processing m=3, n=13, is_special=False
# Processing m=3, n=14, is_special=False
# Processing m=3, n=15, is_special=False
# Processing m=3, n=16, is_special=False
# Processing m=3, n=17, is_special=False
# Processing m=3, n=18, is_special=False
# Processing m=3, n=19, is_special=False
# Processing m=3, n=20, is_special=False
# Processing m=3, n=21, is_special=False
# Processing m=3, n=22, is_special=False
# Processing m=3, n=23, is_special=False
# Processing m=3, n=24, is_special=False
# Processing m=3, n=25, is_special=False
# Processing m=3, n=26, is_special=False
# Processing m=3, n=27, is_special=False
# Processing m=3, n=28, is_special=False
# Processing m=3, n=29, is_special=False
# Processing m=3, n=30, is_special=False
# Processing m=3, n=31, is_special=False
# Processing m=3, n=32, is_special=False
# Processing m=3, n=33, is_special=False
# Processing m=3, n=34, is_special=False
# Processing m=3, n=35, is_special=False
# Processing m=3, n=36, is_special=False
# Processing m=3, n=37, is_special=False
# Processing m=3, n=38, is_special=False
# Processing m=3, n=39, is_special=False
# Processing m=3, n=40, is_special=False
# Processing m=3, n=41, is_special=False
# Processing m=3, n=42, is_special=False
# Processing m=3, n=43, is_special=False
# Processing m=3, n=44, is_special=False
# Processing m=3, n=45, is_special=False
# Processing m=3, n=46, is_special=False
# Processing m=3, n=47, is_special=False
# Processing m=3, n=48, is_special=False
# Processing m=3, n=49, is_special=False
# Processing m=3, n=50, is_special=False
# Processing m=3, n=51, is_special=False
# Processing m=3, n=52, is_special=False
# Processing m=3, n=53, is_special=False
# Processing m=3, n=54, is_special=False
# Processing m=3, n=55, is_special=False
# Processing m=3, n=56, is_special=False
# Processing m=3, n=57, is_special=False
# Processing m=3, n=58, is_special=False
# Processing m=3, n=59, is_special=False
# Processing m=3, n=60, is_special=False
# Processing m=3, n=61, is_special=False
# Processing m=3, n=62, is_special=False
# Processing m=3, n=63, is_special=False
# Processing m=3, n=64, is_special=False
# Processing m=3, n=65, is_special=False
# Processing m=3, n=66, is_special=False
# Processing m=3, n=67, is_special=False
# Processing m=3, n=68, is_special=False
# Processing m=3, n=69, is_special=False
# Processing m=3, n=70, is_special=False
# Processing m=3, n=71, is_special=False
# Processing m=3, n=72, is_special=False
# Processing m=3, n=73, is_special=False
# Processing m=3, n=74, is_special=False
# Processing m=3, n=75, is_special=False
# Processing m=3, n=76, is_special=False
# Processing m=3, n=77, is_special=False
# Processing m=3, n=78, is_special=False
# Processing m=3, n=79, is_special=False
# Processing m=3, n=80, is_special=False
# Processing m=3, n=81, is_special=False
# Processing m=3, n=82, is_special=False
# Processing m=3, n=83, is_special=False
# Processing m=3, n=84, is_special=False
# Processing m=3, n=85, is_special=False
# Processing m=3, n=86, is_special=False
# Processing m=3, n=87, is_special=False
# Processing m=3, n=88, is_special=False
# Processing m=3, n=89, is_special=False
# Processing m=3, n=90, is_special=False
# Processing m=4, n=0, is_special=False
# Processing m=4, n=1, is_special=False
# Processing m=4, n=2, is_special=False
# Processing m=4, n=3, is_special=False
# Processing m=4, n=4, is_special=False
# Processing m=4, n=5, is_special=False
# Processing m=4, n=6, is_special=False
# Processing m=4, n=7, is_special=False
# Processing m=4, n=8, is_special=False
# Processing m=4, n=9, is_special=False
# Processing m=4, n=10, is_special=False
# Processing m=4, n=11, is_special=False
# Processing m=4, n=12, is_special=False
# Processing m=4, n=13, is_special=False
# Processing m=4, n=14, is_special=False
# Processing m=4, n=15, is_special=False
# Processing m=4, n=16, is_special=False
# Processing m=4, n=17, is_special=False
# Processing m=4, n=18, is_special=False
# Processing m=4, n=19, is_special=False
# Processing m=4, n=20, is_special=False
# Processing m=4, n=21, is_special=False
# Processing m=4, n=22, is_special=False
# Processing m=4, n=23, is_special=False
# Processing m=4, n=24, is_special=False
# Processing m=4, n=25, is_special=False
# Processing m=4, n=26, is_special=False
# Processing m=4, n=27, is_special=False
# Processing m=4, n=28, is_special=False
# Processing m=4, n=29, is_special=False
# Processing m=4, n=30, is_special=False
# Processing m=4, n=31, is_special=False
# Processing m=4, n=32, is_special=False
# Processing m=4, n=33, is_special=False
# Processing m=4, n=34, is_special=False
# Processing m=4, n=35, is_special=False
# Processing m=4, n=36, is_special=False
# Processing m=4, n=37, is_special=False
# Processing m=4, n=38, is_special=False
# Processing m=4, n=39, is_special=False
# Processing m=4, n=40, is_special=False
# Processing m=4, n=41, is_special=False
# Processing m=4, n=42, is_special=False
# Processing m=4, n=43, is_special=False
# Processing m=4, n=44, is_special=False
# Processing m=4, n=45, is_special=False
# Processing m=4, n=46, is_special=False
# Processing m=4, n=47, is_special=False
# Processing m=4, n=48, is_special=False
# Processing m=4, n=49, is_special=False
# Processing m=4, n=50, is_special=False
# Processing m=4, n=51, is_special=False
# Processing m=4, n=52, is_special=False
# Processing m=4, n=53, is_special=False
# Processing m=4, n=54, is_special=False
# Processing m=4, n=55, is_special=False
# Processing m=4, n=56, is_special=False
# Processing m=4, n=57, is_special=False
# Processing m=4, n=58, is_special=False
# Processing m=4, n=59, is_special=False
# Processing m=4, n=60, is_special=False
# Processing m=4, n=61, is_special=False
# Processing m=4, n=62, is_special=False
# Processing m=4, n=63, is_special=False
# Processing m=4, n=64, is_special=False
# Processing m=4, n=65, is_special=False
# Processing m=4, n=66, is_special=False
# Processing m=4, n=67, is_special=False
# Processing m=4, n=68, is_special=False
# Processing m=4, n=69, is_special=False
# Processing m=4, n=70, is_special=False
# Processing m=4, n=71, is_special=False
# Processing m=4, n=72, is_special=False
# Processing m=4, n=73, is_special=False
# Processing m=4, n=74, is_special=False
# Processing m=4, n=75, is_special=False
# Processing m=4, n=76, is_special=False
# Processing m=4, n=77, is_special=False
# Processing m=4, n=78, is_special=False
# Processing m=4, n=79, is_special=False
# Processing m=4, n=80, is_special=False
# Processing m=4, n=81, is_special=False
# Processing m=4, n=82, is_special=False
# Processing m=4, n=83, is_special=False
# Processing m=4, n=84, is_special=False
# Processing m=4, n=85, is_special=False
# Processing m=4, n=86, is_special=False
# Processing m=4, n=87, is_special=False
# Processing m=4, n=88, is_special=False
# Processing m=4, n=89, is_special=False
# Processing m=4, n=90, is_special=False
# Processing m=5, n=0, is_special=False
# Processing m=5, n=1, is_special=False
# Processing m=5, n=2, is_special=False
# Processing m=5, n=3, is_special=False
# Processing m=5, n=4, is_special=False
# Processing m=5, n=5, is_special=False
# Processing m=5, n=6, is_special=False
# Processing m=5, n=7, is_special=False
# Processing m=5, n=8, is_special=False
# Processing m=5, n=9, is_special=False
# Processing m=5, n=10, is_special=False
# Processing m=5, n=11, is_special=False
# Processing m=5, n=12, is_special=False
# Processing m=5, n=13, is_special=False
# Processing m=5, n=14, is_special=False
# Processing m=5, n=15, is_special=False
# Processing m=5, n=16, is_special=False
# Processing m=5, n=17, is_special=False
# Processing m=5, n=18, is_special=False
# Processing m=5, n=19, is_special=False
# Processing m=5, n=20, is_special=False
# Processing m=5, n=21, is_special=False
# Processing m=5, n=22, is_special=False
# Processing m=5, n=23, is_special=False
# Processing m=5, n=24, is_special=False
# Processing m=5, n=25, is_special=False
# Processing m=5, n=26, is_special=False
# Processing m=5, n=27, is_special=False
# Processing m=5, n=28, is_special=False
# Processing m=5, n=29, is_special=False
# Processing m=5, n=30, is_special=False
# Processing m=5, n=31, is_special=False
# Processing m=5, n=32, is_special=False
# Processing m=5, n=33, is_special=False
# Processing m=5, n=34, is_special=False
# Processing m=5, n=35, is_special=False
# Processing m=5, n=36, is_special=False
# Processing m=5, n=37, is_special=False
# Processing m=5, n=38, is_special=False
# Processing m=5, n=39, is_special=False
# Processing m=5, n=40, is_special=False
# Processing m=5, n=41, is_special=False
# Processing m=5, n=42, is_special=False
# Processing m=5, n=43, is_special=False
# Processing m=5, n=44, is_special=False
# Processing m=5, n=45, is_special=False
# Processing m=5, n=46, is_special=False
# Processing m=5, n=47, is_special=False
# Processing m=5, n=48, is_special=False
# Processing m=5, n=49, is_special=False
# Processing m=5, n=50, is_special=False
# Processing m=5, n=51, is_special=False
# Processing m=5, n=52, is_special=False
# Processing m=5, n=53, is_special=False
# Processing m=5, n=54, is_special=False
# Processing m=5, n=55, is_special=False
# Processing m=5, n=56, is_special=False
# Processing m=5, n=57, is_special=False
# Processing m=5, n=58, is_special=False
# Processing m=5, n=59, is_special=False
# Processing m=5, n=60, is_special=False
# Processing m=5, n=61, is_special=False
# Processing m=5, n=62, is_special=False
# Processing m=5, n=63, is_special=False
# Processing m=5, n=64, is_special=False
# Processing m=5, n=65, is_special=False
# Processing m=5, n=66, is_special=False
# Processing m=5, n=67, is_special=False
# Processing m=5, n=68, is_special=False
# Processing m=5, n=69, is_special=False
# Processing m=5, n=70, is_special=False
# Processing m=5, n=71, is_special=False
# Processing m=5, n=72, is_special=False
# Processing m=5, n=73, is_special=False
# Processing m=5, n=74, is_special=False
# Processing m=5, n=75, is_special=False
# Processing m=5, n=76, is_special=False
# Processing m=5, n=77, is_special=False
# Processing m=5, n=78, is_special=False
# Processing m=5, n=79, is_special=False
# Processing m=5, n=80, is_special=False
# Processing m=5, n=81, is_special=False
# Processing m=5, n=82, is_special=False
# Processing m=5, n=83, is_special=False
# Processing m=5, n=84, is_special=False
# Processing m=5, n=85, is_special=False
# Processing m=5, n=86, is_special=False
# Processing m=5, n=87, is_special=False
# Processing m=5, n=88, is_special=False
# Processing m=5, n=89, is_special=False
# Processing m=5, n=90, is_special=False
# Processing m=6, n=0, is_special=False
# Processing m=6, n=1, is_special=False
# Processing m=6, n=2, is_special=False
# Processing m=6, n=3, is_special=False
# Processing m=6, n=4, is_special=False
# Processing m=6, n=5, is_special=False
# Processing m=6, n=6, is_special=False
# Processing m=6, n=7, is_special=False
# Processing m=6, n=8, is_special=False
# Processing m=6, n=9, is_special=False
# Processing m=6, n=10, is_special=False
# Processing m=6, n=11, is_special=False
# Processing m=6, n=12, is_special=False
# Processing m=6, n=13, is_special=False
# Processing m=6, n=14, is_special=False
# Processing m=6, n=15, is_special=False
# Processing m=6, n=16, is_special=False
# Processing m=6, n=17, is_special=False
# Processing m=6, n=18, is_special=False
# Processing m=6, n=19, is_special=False
# Processing m=6, n=20, is_special=False
# Processing m=6, n=21, is_special=False
# Processing m=6, n=22, is_special=False
# Processing m=6, n=23, is_special=False
# Processing m=6, n=24, is_special=False
# Processing m=6, n=25, is_special=False
# Processing m=6, n=26, is_special=False
# Processing m=6, n=27, is_special=False
# Processing m=6, n=28, is_special=False
# Processing m=6, n=29, is_special=False
# Processing m=6, n=30, is_special=False
# Processing m=6, n=31, is_special=False
# Processing m=6, n=32, is_special=False
# Processing m=6, n=33, is_special=False
# Processing m=6, n=34, is_special=False
# Processing m=6, n=35, is_special=False
# Processing m=6, n=36, is_special=False
# Processing m=6, n=37, is_special=False
# Processing m=6, n=38, is_special=False
# Processing m=6, n=39, is_special=False
# Processing m=6, n=40, is_special=False
# Processing m=6, n=41, is_special=False
# Processing m=6, n=42, is_special=False
# Processing m=6, n=43, is_special=False
# Processing m=6, n=44, is_special=False
# Processing m=6, n=45, is_special=False
# Processing m=6, n=46, is_special=False
# Processing m=6, n=47, is_special=False
# Processing m=6, n=48, is_special=False
# Processing m=6, n=49, is_special=False
# Processing m=6, n=50, is_special=False
# Processing m=6, n=51, is_special=False
# Processing m=6, n=52, is_special=False
# Processing m=6, n=53, is_special=False
# Processing m=6, n=54, is_special=False
# Processing m=6, n=55, is_special=False
# Processing m=6, n=56, is_special=False
# Processing m=6, n=57, is_special=False
# Processing m=6, n=58, is_special=False
# Processing m=6, n=59, is_special=False
# Processing m=6, n=60, is_special=False
# Processing m=6, n=61, is_special=False
# Processing m=6, n=62, is_special=False
# Processing m=6, n=63, is_special=False
# Processing m=6, n=64, is_special=False
# Processing m=6, n=65, is_special=False
# Processing m=6, n=66, is_special=False
# Processing m=6, n=67, is_special=False
# Processing m=6, n=68, is_special=False
# Processing m=6, n=69, is_special=False
# Processing m=6, n=70, is_special=False
# Processing m=6, n=71, is_special=False
# Processing m=6, n=72, is_special=False
# Processing m=6, n=73, is_special=False
# Processing m=6, n=74, is_special=False
# Processing m=6, n=75, is_special=False
# Processing m=6, n=76, is_special=False
# Processing m=6, n=77, is_special=False
# Processing m=6, n=78, is_special=False
# Processing m=6, n=79, is_special=False
# Processing m=6, n=80, is_special=False
# Processing m=6, n=81, is_special=False
# Processing m=6, n=82, is_special=False
# Processing m=6, n=83, is_special=False
# Processing m=6, n=84, is_special=False
# Processing m=6, n=85, is_special=False
# Processing m=6, n=86, is_special=False
# Processing m=6, n=87, is_special=False
# Processing m=6, n=88, is_special=False
# Processing m=6, n=89, is_special=False
# Processing m=6, n=90, is_special=False
# Processing m=7, n=0, is_special=False
# Processing m=7, n=1, is_special=False
# Processing m=7, n=2, is_special=False
# Processing m=7, n=3, is_special=False
# Processing m=7, n=4, is_special=False
# Processing m=7, n=5, is_special=False
# Processing m=7, n=6, is_special=False
# Processing m=7, n=7, is_special=False
# Processing m=7, n=8, is_special=False
# Processing m=7, n=9, is_special=False
# Processing m=7, n=10, is_special=False
# Processing m=7, n=11, is_special=False
# Processing m=7, n=12, is_special=False
# Processing m=7, n=13, is_special=False
# Processing m=7, n=14, is_special=False
# Processing m=7, n=15, is_special=False
# Processing m=7, n=16, is_special=False
# Processing m=7, n=17, is_special=False
# Processing m=7, n=18, is_special=False
# Processing m=7, n=19, is_special=False
# Processing m=7, n=20, is_special=False
# Processing m=7, n=21, is_special=False
# Processing m=7, n=22, is_special=False
# Processing m=7, n=23, is_special=False
# Processing m=7, n=24, is_special=False
# Processing m=7, n=25, is_special=False
# Processing m=7, n=26, is_special=False
# Processing m=7, n=27, is_special=False
# Processing m=7, n=28, is_special=False
# Processing m=7, n=29, is_special=False
# Processing m=7, n=30, is_special=False
# Processing m=7, n=31, is_special=False
# Processing m=7, n=32, is_special=False
# Processing m=7, n=33, is_special=False
# Processing m=7, n=34, is_special=False
# Processing m=7, n=35, is_special=False
# Processing m=7, n=36, is_special=False
# Processing m=7, n=37, is_special=False
# Processing m=7, n=38, is_special=False
# Processing m=7, n=39, is_special=False
# Processing m=7, n=40, is_special=False
# Processing m=7, n=41, is_special=False
# Processing m=7, n=42, is_special=False
# Processing m=7, n=43, is_special=False
# Processing m=7, n=44, is_special=False
# Processing m=7, n=45, is_special=False
# Processing m=7, n=46, is_special=False
# Processing m=7, n=47, is_special=False
# Processing m=7, n=48, is_special=False
# Processing m=7, n=49, is_special=False
# Processing m=7, n=50, is_special=False
# Processing m=7, n=51, is_special=False
# Processing m=7, n=52, is_special=False
# Processing m=7, n=53, is_special=False
# Processing m=7, n=54, is_special=False
# Processing m=7, n=55, is_special=False
# Processing m=7, n=56, is_special=False
# Processing m=7, n=57, is_special=False
# Processing m=7, n=58, is_special=False
# Processing m=7, n=59, is_special=False
# Processing m=7, n=60, is_special=False
# Processing m=7, n=61, is_special=False
# Processing m=7, n=62, is_special=False
# Processing m=7, n=63, is_special=False
# Processing m=7, n=64, is_special=False
# Processing m=7, n=65, is_special=False
# Processing m=7, n=66, is_special=False
# Processing m=7, n=67, is_special=False
# Processing m=7, n=68, is_special=False
# Processing m=7, n=69, is_special=False
# Processing m=7, n=70, is_special=False
# Processing m=7, n=71, is_special=False
# Processing m=7, n=72, is_special=False
# Processing m=7, n=73, is_special=False
# Processing m=7, n=74, is_special=False
# Processing m=7, n=75, is_special=False
# Processing m=7, n=76, is_special=False
# Processing m=7, n=77, is_special=False
# Processing m=7, n=78, is_special=False
# Processing m=7, n=79, is_special=False
# Processing m=7, n=80, is_special=False
# Processing m=7, n=81, is_special=False
# Processing m=7, n=82, is_special=False
# Processing m=7, n=83, is_special=False
# Processing m=7, n=84, is_special=False
# Processing m=7, n=85, is_special=False
# Processing m=7, n=86, is_special=False
# Processing m=7, n=87, is_special=False
# Processing m=7, n=88, is_special=False
# Processing m=7, n=89, is_special=False
# Processing m=7, n=90, is_special=False
# Processing m=8, n=0, is_special=False
# Processing m=8, n=1, is_special=False
# Processing m=8, n=2, is_special=False
# Processing m=8, n=3, is_special=False
# Processing m=8, n=4, is_special=False
# Processing m=8, n=5, is_special=False
# Processing m=8, n=6, is_special=False
# Processing m=8, n=7, is_special=False
# Processing m=8, n=8, is_special=False
# Processing m=8, n=9, is_special=False
# Processing m=8, n=10, is_special=False
# Processing m=8, n=11, is_special=False
# Processing m=8, n=12, is_special=False
# Processing m=8, n=13, is_special=False
# Processing m=8, n=14, is_special=False
# Processing m=8, n=15, is_special=False
# Processing m=8, n=16, is_special=False
# Processing m=8, n=17, is_special=False
# Processing m=8, n=18, is_special=False
# Processing m=8, n=19, is_special=False
# Processing m=8, n=20, is_special=False
# Processing m=8, n=21, is_special=False
# Processing m=8, n=22, is_special=False
# Processing m=8, n=23, is_special=False
# Processing m=8, n=24, is_special=False
# Processing m=8, n=25, is_special=False
# Processing m=8, n=26, is_special=False
# Processing m=8, n=27, is_special=False
# Processing m=8, n=28, is_special=False
# Processing m=8, n=29, is_special=False
# Processing m=8, n=30, is_special=False
# Processing m=8, n=31, is_special=False
# Processing m=8, n=32, is_special=False
# Processing m=8, n=33, is_special=False
# Processing m=8, n=34, is_special=False
# Processing m=8, n=35, is_special=False
# Processing m=8, n=36, is_special=False
# Processing m=8, n=37, is_special=False
# Processing m=8, n=38, is_special=False
# Processing m=8, n=39, is_special=False
# Processing m=8, n=40, is_special=False
# Processing m=8, n=41, is_special=False
# Processing m=8, n=42, is_special=False
# Processing m=8, n=43, is_special=False
# Processing m=8, n=44, is_special=False
# Processing m=8, n=45, is_special=False
# Processing m=8, n=46, is_special=False
# Processing m=8, n=47, is_special=False
# Processing m=8, n=48, is_special=False
# Processing m=8, n=49, is_special=False
# Processing m=8, n=50, is_special=False
# Processing m=8, n=51, is_special=False
# Processing m=8, n=52, is_special=False
# Processing m=8, n=53, is_special=False
# Processing m=8, n=54, is_special=False
# Processing m=8, n=55, is_special=False
# Processing m=8, n=56, is_special=False
# Processing m=8, n=57, is_special=False
# Processing m=8, n=58, is_special=False
# Processing m=8, n=59, is_special=False
# Processing m=8, n=60, is_special=False
# Processing m=8, n=61, is_special=False
# Processing m=8, n=62, is_special=False
# Processing m=8, n=63, is_special=False
# Processing m=8, n=64, is_special=False
# Processing m=8, n=65, is_special=False
# Processing m=8, n=66, is_special=False
# Processing m=8, n=67, is_special=False
# Processing m=8, n=68, is_special=False
# Processing m=8, n=69, is_special=False
# Processing m=8, n=70, is_special=False
# Processing m=8, n=71, is_special=False
# Processing m=8, n=72, is_special=False
# Processing m=8, n=73, is_special=False
# Processing m=8, n=74, is_special=False
# Processing m=8, n=75, is_special=False
# Processing m=8, n=76, is_special=False
# Processing m=8, n=77, is_special=False
# Processing m=8, n=78, is_special=False
# Processing m=8, n=79, is_special=False
# Processing m=8, n=80, is_special=False
# Processing m=8, n=81, is_special=False
# Processing m=8, n=82, is_special=False
# Processing m=8, n=83, is_special=False
# Processing m=8, n=84, is_special=False
# Processing m=8, n=85, is_special=False
# Processing m=8, n=86, is_special=False
# Processing m=8, n=87, is_special=False
# Processing m=8, n=88, is_special=False
# Processing m=8, n=89, is_special=False
# Processing m=8, n=90, is_special=False
# Processing m=9, n=0, is_special=False
# Processing m=9, n=1, is_special=False
# Processing m=9, n=2, is_special=False
# Processing m=9, n=3, is_special=False
# Processing m=9, n=4, is_special=False
# Processing m=9, n=5, is_special=False
# Processing m=9, n=6, is_special=False
# Processing m=9, n=7, is_special=False
# Processing m=9, n=8, is_special=False
# Processing m=9, n=9, is_special=False
# Processing m=9, n=10, is_special=False
# Processing m=9, n=11, is_special=False
# Processing m=9, n=12, is_special=False
# Processing m=9, n=13, is_special=False
# Processing m=9, n=14, is_special=False
# Processing m=9, n=15, is_special=False
# Processing m=9, n=16, is_special=False
# Processing m=9, n=17, is_special=False
# Processing m=9, n=18, is_special=False
# Processing m=9, n=19, is_special=False
# Processing m=9, n=20, is_special=False
# Processing m=9, n=21, is_special=False
# Processing m=9, n=22, is_special=False
# Processing m=9, n=23, is_special=False
# Processing m=9, n=24, is_special=False
# Processing m=9, n=25, is_special=False
# Processing m=9, n=26, is_special=False
# Processing m=9, n=27, is_special=False
# Processing m=9, n=28, is_special=False
# Processing m=9, n=29, is_special=False
# Processing m=9, n=30, is_special=False
# Processing m=9, n=31, is_special=False
# Processing m=9, n=32, is_special=False
# Processing m=9, n=33, is_special=False
# Processing m=9, n=34, is_special=False
# Processing m=9, n=35, is_special=False
# Processing m=9, n=36, is_special=False
# Processing m=9, n=37, is_special=False
# Processing m=9, n=38, is_special=False
# Processing m=9, n=39, is_special=False
# Processing m=9, n=40, is_special=False
# Processing m=9, n=41, is_special=False
# Processing m=9, n=42, is_special=False
# Processing m=9, n=43, is_special=False
# Processing m=9, n=44, is_special=False
# Processing m=9, n=45, is_special=False
# Processing m=9, n=46, is_special=False
# Processing m=9, n=47, is_special=False
# Processing m=9, n=48, is_special=False
# Processing m=9, n=49, is_special=False
# Processing m=9, n=50, is_special=False
# Processing m=9, n=51, is_special=False
# Processing m=9, n=52, is_special=False
# Processing m=9, n=53, is_special=False
# Processing m=9, n=54, is_special=False
# Processing m=9, n=55, is_special=False
# Processing m=9, n=56, is_special=False
# Processing m=9, n=57, is_special=False
# Processing m=9, n=58, is_special=False
# Processing m=9, n=59, is_special=False
# Processing m=9, n=60, is_special=False
# Processing m=9, n=61, is_special=False
# Processing m=9, n=62, is_special=False
# Processing m=9, n=63, is_special=False
# Processing m=9, n=64, is_special=False
# Processing m=9, n=65, is_special=False
# Processing m=9, n=66, is_special=False
# Processing m=9, n=67, is_special=False
# Processing m=9, n=68, is_special=False
# Processing m=9, n=69, is_special=False
# Processing m=9, n=70, is_special=False
# Processing m=9, n=71, is_special=False
# Processing m=9, n=72, is_special=False
# Processing m=9, n=73, is_special=False
# Processing m=9, n=74, is_special=False
# Processing m=9, n=75, is_special=False
# Processing m=9, n=76, is_special=False
# Processing m=9, n=77, is_special=False
# Processing m=9, n=78, is_special=False
# Processing m=9, n=79, is_special=False
# Processing m=9, n=80, is_special=False
# Processing m=9, n=81, is_special=False
# Processing m=9, n=82, is_special=False
# Processing m=9, n=83, is_special=False
# Processing m=9, n=84, is_special=False
# Processing m=9, n=85, is_special=False
# Processing m=9, n=86, is_special=False
# Processing m=9, n=87, is_special=False
# Processing m=9, n=88, is_special=False
# Processing m=9, n=89, is_special=False
# Processing m=9, n=90, is_special=False
# Processing m=10, n=0, is_special=False
# Processing m=10, n=1, is_special=False
# Processing m=10, n=2, is_special=False
# Processing m=10, n=3, is_special=False
# Processing m=10, n=4, is_special=False
# Processing m=10, n=5, is_special=False
# Processing m=10, n=6, is_special=False
# Processing m=10, n=7, is_special=False
# Processing m=10, n=8, is_special=False
# Processing m=10, n=9, is_special=False
# Processing m=10, n=10, is_special=False
# Processing m=10, n=11, is_special=False
# Processing m=10, n=12, is_special=False
# Processing m=10, n=13, is_special=False
# Processing m=10, n=14, is_special=False
# Processing m=10, n=15, is_special=False
# Processing m=10, n=16, is_special=False
# Processing m=10, n=17, is_special=False
# Processing m=10, n=18, is_special=False
# Processing m=10, n=19, is_special=False
# Processing m=10, n=20, is_special=False
# Processing m=10, n=21, is_special=False
# Processing m=10, n=22, is_special=False
# Processing m=10, n=23, is_special=False
# Processing m=10, n=24, is_special=False
# Processing m=10, n=25, is_special=False
# Processing m=10, n=26, is_special=False
# Processing m=10, n=27, is_special=False
# Processing m=10, n=28, is_special=False
# Processing m=10, n=29, is_special=False
# Processing m=10, n=30, is_special=False
# Processing m=10, n=31, is_special=False
# Processing m=10, n=32, is_special=False
# Processing m=10, n=33, is_special=False
# Processing m=10, n=34, is_special=False
# Processing m=10, n=35, is_special=False
# Processing m=10, n=36, is_special=False
# Processing m=10, n=37, is_special=False
# Processing m=10, n=38, is_special=False
# Processing m=10, n=39, is_special=False
# Processing m=10, n=40, is_special=False
# Processing m=10, n=41, is_special=False
# Processing m=10, n=42, is_special=False
# Processing m=10, n=43, is_special=False
# Processing m=10, n=44, is_special=False
# Processing m=10, n=45, is_special=False
# Processing m=10, n=46, is_special=False
# Processing m=10, n=47, is_special=False
# Processing m=10, n=48, is_special=False
# Processing m=10, n=49, is_special=False
# Processing m=10, n=50, is_special=False
# Processing m=10, n=51, is_special=False
# Processing m=10, n=52, is_special=False
# Processing m=10, n=53, is_special=False
# Processing m=10, n=54, is_special=False
# Processing m=10, n=55, is_special=False
# Processing m=10, n=56, is_special=False
# Processing m=10, n=57, is_special=False
# Processing m=10, n=58, is_special=False
# Processing m=10, n=59, is_special=False
# Processing m=10, n=60, is_special=False
# Processing m=10, n=61, is_special=False
# Processing m=10, n=62, is_special=False
# Processing m=10, n=63, is_special=False
# Processing m=10, n=64, is_special=False
# Processing m=10, n=65, is_special=False
# Processing m=10, n=66, is_special=False
# Processing m=10, n=67, is_special=False
# Processing m=10, n=68, is_special=False
# Processing m=10, n=69, is_special=False
# Processing m=10, n=70, is_special=False
# Processing m=10, n=71, is_special=False
# Processing m=10, n=72, is_special=False
# Processing m=10, n=73, is_special=False
# Processing m=10, n=74, is_special=False
# Processing m=10, n=75, is_special=False
# Processing m=10, n=76, is_special=False
# Processing m=10, n=77, is_special=False
# Processing m=10, n=78, is_special=False
# Processing m=10, n=79, is_special=False
# Processing m=10, n=80, is_special=False
# Processing m=10, n=81, is_special=False
# Processing m=10, n=82, is_special=False
# Processing m=10, n=83, is_special=False
# Processing m=10, n=84, is_special=False
# Processing m=10, n=85, is_special=False
# Processing m=10, n=86, is_special=False
# Processing m=10, n=87, is_special=False
# Processing m=10, n=88, is_special=False
# Processing m=10, n=89, is_special=False
# Processing m=10, n=90, is_special=False
# Processing m=11, n=0, is_special=False
# Processing m=11, n=1, is_special=False
# Processing m=11, n=2, is_special=False
# Processing m=11, n=3, is_special=False
# Processing m=11, n=4, is_special=False
# Processing m=11, n=5, is_special=False
# Processing m=11, n=6, is_special=False
# Processing m=11, n=7, is_special=False
# Processing m=11, n=8, is_special=False
# Processing m=11, n=9, is_special=False
# Processing m=11, n=10, is_special=False
# Processing m=11, n=11, is_special=False
# Processing m=11, n=12, is_special=False
# Processing m=11, n=13, is_special=False
# Processing m=11, n=14, is_special=False
# Processing m=11, n=15, is_special=False
# Processing m=11, n=16, is_special=False
# Processing m=11, n=17, is_special=False
# Processing m=11, n=18, is_special=False
# Processing m=11, n=19, is_special=False
# Processing m=11, n=20, is_special=False
# Processing m=11, n=21, is_special=False
# Processing m=11, n=22, is_special=False
# Processing m=11, n=23, is_special=False
# Processing m=11, n=24, is_special=False
# Processing m=11, n=25, is_special=False
# Processing m=11, n=26, is_special=False
# Processing m=11, n=27, is_special=False
# Processing m=11, n=28, is_special=False
# Processing m=11, n=29, is_special=False
# Processing m=11, n=30, is_special=False
# Processing m=11, n=31, is_special=False
# Processing m=11, n=32, is_special=False
# Processing m=11, n=33, is_special=False
# Processing m=11, n=34, is_special=False
# Processing m=11, n=35, is_special=False
# Processing m=11, n=36, is_special=False
# Processing m=11, n=37, is_special=False
# Processing m=11, n=38, is_special=False
# Processing m=11, n=39, is_special=False
# Processing m=11, n=40, is_special=False
# Processing m=11, n=41, is_special=False
# Processing m=11, n=42, is_special=False
# Processing m=11, n=43, is_special=False
# Processing m=11, n=44, is_special=False
# Processing m=11, n=45, is_special=False
# Processing m=11, n=46, is_special=False
# Processing m=11, n=47, is_special=False
# Processing m=11, n=48, is_special=False
# Processing m=11, n=49, is_special=False
# Processing m=11, n=50, is_special=False
# Processing m=11, n=51, is_special=False
# Processing m=11, n=52, is_special=False
# Processing m=11, n=53, is_special=False
# Processing m=11, n=54, is_special=False
# Processing m=11, n=55, is_special=False
# Processing m=11, n=56, is_special=False
# Processing m=11, n=57, is_special=False
# Processing m=11, n=58, is_special=False
# Processing m=11, n=59, is_special=False
# Processing m=11, n=60, is_special=False
# Processing m=11, n=61, is_special=False
# Processing m=11, n=62, is_special=False
# Processing m=11, n=63, is_special=False
# Processing m=11, n=64, is_special=False
# Processing m=11, n=65, is_special=False
# Processing m=11, n=66, is_special=False
# Processing m=11, n=67, is_special=False
# Processing m=11, n=68, is_special=False
# Processing m=11, n=69, is_special=False
# Processing m=11, n=70, is_special=False
# Processing m=11, n=71, is_special=False
# Processing m=11, n=72, is_special=False
# Processing m=11, n=73, is_special=False
# Processing m=11, n=74, is_special=False
# Processing m=11, n=75, is_special=False
# Processing m=11, n=76, is_special=False
# Processing m=11, n=77, is_special=False
# Processing m=11, n=78, is_special=False
# Processing m=11, n=79, is_special=False
# Processing m=11, n=80, is_special=False
# Processing m=11, n=81, is_special=False
# Processing m=11, n=82, is_special=False
# Processing m=11, n=83, is_special=False
# Processing m=11, n=84, is_special=False
# Processing m=11, n=85, is_special=False
# Processing m=11, n=86, is_special=False
# Processing m=11, n=87, is_special=False
# Processing m=11, n=88, is_special=False
# Processing m=11, n=89, is_special=False
# Processing m=11, n=90, is_special=False
# Processing m=12, n=0, is_special=False
# Processing m=12, n=1, is_special=False
# Processing m=12, n=2, is_special=False
# Processing m=12, n=3, is_special=False
# Processing m=12, n=4, is_special=False
# Processing m=12, n=5, is_special=False
# Processing m=12, n=6, is_special=False
# Processing m=12, n=7, is_special=False
# Processing m=12, n=8, is_special=False
# Processing m=12, n=9, is_special=False
# Processing m=12, n=10, is_special=False
# Processing m=12, n=11, is_special=False
# Processing m=12, n=12, is_special=False
# Processing m=12, n=13, is_special=False
# Processing m=12, n=14, is_special=False
# Processing m=12, n=15, is_special=False
# Processing m=12, n=16, is_special=False
# Processing m=12, n=17, is_special=False
# Processing m=12, n=18, is_special=False
# Processing m=12, n=19, is_special=False
# Processing m=12, n=20, is_special=False
# Processing m=12, n=21, is_special=False
# Processing m=12, n=22, is_special=False
# Processing m=12, n=23, is_special=False
# Processing m=12, n=24, is_special=False
# Processing m=12, n=25, is_special=False
# Processing m=12, n=26, is_special=False
# Processing m=12, n=27, is_special=False
# Processing m=12, n=28, is_special=False
# Processing m=12, n=29, is_special=False
# Processing m=12, n=30, is_special=False
# Processing m=12, n=31, is_special=False
# Processing m=12, n=32, is_special=False
# Processing m=12, n=33, is_special=False
# Processing m=12, n=34, is_special=False
# Processing m=12, n=35, is_special=False
# Processing m=12, n=36, is_special=False
# Processing m=12, n=37, is_special=False
# Processing m=12, n=38, is_special=False
# Processing m=12, n=39, is_special=False
# Processing m=12, n=40, is_special=False
# Processing m=12, n=41, is_special=False
# Processing m=12, n=42, is_special=False
# Processing m=12, n=43, is_special=False
# Processing m=12, n=44, is_special=False
# Processing m=12, n=45, is_special=False
# Processing m=12, n=46, is_special=False
# Processing m=12, n=47, is_special=False
# Processing m=12, n=48, is_special=False
# Processing m=12, n=49, is_special=False
# Processing m=12, n=50, is_special=False
# Processing m=12, n=51, is_special=False
# Processing m=12, n=52, is_special=False
# Processing m=12, n=53, is_special=False
# Processing m=12, n=54, is_special=False
# Processing m=12, n=55, is_special=False
# Processing m=12, n=56, is_special=False
# Processing m=12, n=57, is_special=False
# Processing m=12, n=58, is_special=False
# Processing m=12, n=59, is_special=False
# Processing m=12, n=60, is_special=False
# Processing m=12, n=61, is_special=False
# Processing m=12, n=62, is_special=False
# Processing m=12, n=63, is_special=False
# Processing m=12, n=64, is_special=False
# Processing m=12, n=65, is_special=False
# Processing m=12, n=66, is_special=False
# Processing m=12, n=67, is_special=False
# Processing m=12, n=68, is_special=False
# Processing m=12, n=69, is_special=False
# Processing m=12, n=70, is_special=False
# Processing m=12, n=71, is_special=False
# Processing m=12, n=72, is_special=False
# Processing m=12, n=73, is_special=False
# Processing m=12, n=74, is_special=False
# Processing m=12, n=75, is_special=False
# Processing m=12, n=76, is_special=False
# Processing m=12, n=77, is_special=False
# Processing m=12, n=78, is_special=False
# Processing m=12, n=79, is_special=False
# Processing m=12, n=80, is_special=False
# Processing m=12, n=81, is_special=False
# Processing m=12, n=82, is_special=False
# Processing m=12, n=83, is_special=False
# Processing m=12, n=84, is_special=False
# Processing m=12, n=85, is_special=False
# Processing m=12, n=86, is_special=False
# Processing m=12, n=87, is_special=False
# Processing m=12, n=88, is_special=False
# Processing m=12, n=89, is_special=False
# Processing m=12, n=90, is_special=False
# Processing m=13, n=0, is_special=False
# Processing m=13, n=1, is_special=False
# Processing m=13, n=2, is_special=False
# Processing m=13, n=3, is_special=False
# Processing m=13, n=4, is_special=False
# Processing m=13, n=5, is_special=False
# Processing m=13, n=6, is_special=False
# Processing m=13, n=7, is_special=False
# Processing m=13, n=8, is_special=False
# Processing m=13, n=9, is_special=False
# Processing m=13, n=10, is_special=False
# Processing m=13, n=11, is_special=False
# Processing m=13, n=12, is_special=False
# Processing m=13, n=13, is_special=False
# Processing m=13, n=14, is_special=False
# Processing m=13, n=15, is_special=False
# Processing m=13, n=16, is_special=False
# Processing m=13, n=17, is_special=False
# Processing m=13, n=18, is_special=False
# Processing m=13, n=19, is_special=False
# Processing m=13, n=20, is_special=False
# Processing m=13, n=21, is_special=False
# Processing m=13, n=22, is_special=False
# Processing m=13, n=23, is_special=False
# Processing m=13, n=24, is_special=False
# Processing m=13, n=25, is_special=False
# Processing m=13, n=26, is_special=False
# Processing m=13, n=27, is_special=False
# Processing m=13, n=28, is_special=False
# Processing m=13, n=29, is_special=False
# Processing m=13, n=30, is_special=False
# Processing m=13, n=31, is_special=False
# Processing m=13, n=32, is_special=False
# Processing m=13, n=33, is_special=False
# Processing m=13, n=34, is_special=False
# Processing m=13, n=35, is_special=False
# Processing m=13, n=36, is_special=False
# Processing m=13, n=37, is_special=False
# Processing m=13, n=38, is_special=False
# Processing m=13, n=39, is_special=False
# Processing m=13, n=40, is_special=False
# Processing m=13, n=41, is_special=False
# Processing m=13, n=42, is_special=False
# ...
# Processing m=359, n=64, is_special=False
# Processing m=359, n=65, is_special=False
# Processing m=359, n=66, is_special=False
# Processing m=359, n=67, is_special=False
# Processing m=359, n=68, is_special=False
# Processing m=359, n=69, is_special=False
# Processing m=359, n=70, is_special=False
# Processing m=359, n=71, is_special=False
# Processing m=359, n=72, is_special=False
# Processing m=359, n=73, is_special=False
# Processing m=359, n=74, is_special=False
# Processing m=359, n=75, is_special=False
# Processing m=359, n=76, is_special=False
# Processing m=359, n=77, is_special=False
# Processing m=359, n=78, is_special=False
# Processing m=359, n=79, is_special=False
# Processing m=359, n=80, is_special=False
# Processing m=359, n=81, is_special=False
# Processing m=359, n=82, is_special=False
# Processing m=359, n=83, is_special=False
# Processing m=359, n=84, is_special=False
# Processing m=359, n=85, is_special=False
# Processing m=359, n=86, is_special=False
# Processing m=359, n=87, is_special=False
# Processing m=359, n=88, is_special=False
# Processing m=359, n=89, is_special=False
# Processing m=359, n=90, is_special=False
# Processing m=360, n=0, is_special=False
# Processing m=360, n=1, is_special=False
# Processing m=360, n=2, is_special=False
# Processing m=360, n=3, is_special=False
# Processing m=360, n=4, is_special=False
# Processing m=360, n=5, is_special=False
# Processing m=360, n=6, is_special=False
# Processing m=360, n=7, is_special=False
# Processing m=360, n=8, is_special=False
# Processing m=360, n=9, is_special=False
# Processing m=360, n=10, is_special=False
# Processing m=360, n=11, is_special=False
# Processing m=360, n=12, is_special=False
# Processing m=360, n=13, is_special=False
# Processing m=360, n=14, is_special=False
# Processing m=360, n=15, is_special=False
# Processing m=360, n=16, is_special=False
# Processing m=360, n=17, is_special=False
# Processing m=360, n=18, is_special=False
# Processing m=360, n=19, is_special=False
# Processing m=360, n=20, is_special=False
# Processing m=360, n=21, is_special=False
# Processing m=360, n=22, is_special=False
# Processing m=360, n=23, is_special=False
# Processing m=360, n=24, is_special=False
# Processing m=360, n=25, is_special=False
# Processing m=360, n=26, is_special=False
# Processing m=360, n=27, is_special=False
# Processing m=360, n=28, is_special=False
# Processing m=360, n=29, is_special=False
# Processing m=360, n=30, is_special=False
# Processing m=360, n=31, is_special=False
# Processing m=360, n=32, is_special=False
# Processing m=360, n=33, is_special=False
# Processing m=360, n=34, is_special=False
# Processing m=360, n=35, is_special=False
# Processing m=360, n=36, is_special=False
# Processing m=360, n=37, is_special=False
# Processing m=360, n=38, is_special=False
# Processing m=360, n=39, is_special=False
# Processing m=360, n=40, is_special=False
# Processing m=360, n=41, is_special=False
# Processing m=360, n=42, is_special=False
# Processing m=360, n=43, is_special=False
# Processing m=360, n=44, is_special=False
# Processing m=360, n=45, is_special=False
# Processing m=360, n=46, is_special=False
# Processing m=360, n=47, is_special=False
# Processing m=360, n=48, is_special=False
# Processing m=360, n=49, is_special=False
# Processing m=360, n=50, is_special=False
# Processing m=360, n=51, is_special=False
# Processing m=360, n=52, is_special=False
# Processing m=360, n=53, is_special=False
# Processing m=360, n=54, is_special=False
# Processing m=360, n=55, is_special=False
# Processing m=360, n=56, is_special=False
# Processing m=360, n=57, is_special=False
# Processing m=360, n=58, is_special=False
# Processing m=360, n=59, is_special=False
# Processing m=360, n=60, is_special=False
# Processing m=360, n=61, is_special=False
# Processing m=360, n=62, is_special=False
# Processing m=360, n=63, is_special=False
# Processing m=360, n=64, is_special=False
# Processing m=360, n=65, is_special=False
# Processing m=360, n=66, is_special=False
# Processing m=360, n=67, is_special=False
# Processing m=360, n=68, is_special=False
# Processing m=360, n=69, is_special=False
# Processing m=360, n=70, is_special=False
# Processing m=360, n=71, is_special=False
# Processing m=360, n=72, is_special=False
# Processing m=360, n=73, is_special=False
# Processing m=360, n=74, is_special=False
# Processing m=360, n=75, is_special=False
# Processing m=360, n=76, is_special=False
# Processing m=360, n=77, is_special=False
# Processing m=360, n=78, is_special=False
# Processing m=360, n=79, is_special=False
# Processing m=360, n=80, is_special=False
# Processing m=360, n=81, is_special=False
# Processing m=360, n=82, is_special=False
# Processing m=360, n=83, is_special=False
# Processing m=360, n=84, is_special=False
# Processing m=360, n=85, is_special=False
# Processing m=360, n=86, is_special=False
# Processing m=360, n=87, is_special=False
# Processing m=360, n=88, is_special=False
# Processing m=360, n=89, is_special=False
# Processing m=360, n=90, is_special=False
# Processing m=361, n=0, is_special=False
# Processing m=361, n=1, is_special=False
# Processing m=361, n=2, is_special=False
# Processing m=361, n=3, is_special=False
# Processing m=361, n=4, is_special=False
# Processing m=361, n=5, is_special=False
# Processing m=361, n=6, is_special=False
# Processing m=361, n=7, is_special=False
# Processing m=361, n=8, is_special=False
# Processing m=361, n=9, is_special=False
# Processing m=361, n=10, is_special=False
# Processing m=361, n=11, is_special=False
# Processing m=361, n=12, is_special=False
# Processing m=361, n=13, is_special=False
# Processing m=361, n=14, is_special=False
# Processing m=361, n=15, is_special=False
# Processing m=361, n=16, is_special=False
# Processing m=361, n=17, is_special=False
# Processing m=361, n=18, is_special=False
# Processing m=361, n=19, is_special=False
# Processing m=361, n=20, is_special=False
# Processing m=361, n=21, is_special=False
# Processing m=361, n=22, is_special=False
# Processing m=361, n=23, is_special=False
# Processing m=361, n=24, is_special=False
# Processing m=361, n=25, is_special=False
# Processing m=361, n=26, is_special=False
# Processing m=361, n=27, is_special=False
# Processing m=361, n=28, is_special=False
# Processing m=361, n=29, is_special=False
# Processing m=361, n=30, is_special=False
# Processing m=361, n=31, is_special=False
# Processing m=361, n=32, is_special=False
# Processing m=361, n=33, is_special=False
# Processing m=361, n=34, is_special=False
# Processing m=361, n=35, is_special=False
# Processing m=361, n=36, is_special=False
# Processing m=361, n=37, is_special=False
# Processing m=361, n=38, is_special=False
# Processing m=361, n=39, is_special=False
# Processing m=361, n=40, is_special=False
# Processing m=361, n=41, is_special=False
# Processing m=361, n=42, is_special=False
# Processing m=361, n=43, is_special=False
# Processing m=361, n=44, is_special=False
# Processing m=361, n=45, is_special=False
# Processing m=361, n=46, is_special=False
# Processing m=361, n=47, is_special=False
# Processing m=361, n=48, is_special=False
# Processing m=361, n=49, is_special=False
# Processing m=361, n=50, is_special=False
# Processing m=361, n=51, is_special=False
# Processing m=361, n=52, is_special=False
# Processing m=361, n=53, is_special=False
# Processing m=361, n=54, is_special=False
# Processing m=361, n=55, is_special=False
# Processing m=361, n=56, is_special=False
# Processing m=361, n=57, is_special=False
# Processing m=361, n=58, is_special=False
# Processing m=361, n=59, is_special=False
# Processing m=361, n=60, is_special=False
# Processing m=361, n=61, is_special=False
# Processing m=361, n=62, is_special=False
# Processing m=361, n=63, is_special=False
# Processing m=361, n=64, is_special=False
# Processing m=361, n=65, is_special=False
# Processing m=361, n=66, is_special=False
# Processing m=361, n=67, is_special=False
# Processing m=361, n=68, is_special=False
# Processing m=361, n=69, is_special=False
# Processing m=361, n=70, is_special=False
# Processing m=361, n=71, is_special=False
# Processing m=361, n=72, is_special=False
# Processing m=361, n=73, is_special=False
# Processing m=361, n=74, is_special=False
# Processing m=361, n=75, is_special=False
# Processing m=361, n=76, is_special=False
# Processing m=361, n=77, is_special=False
# Processing m=361, n=78, is_special=False
# Processing m=361, n=79, is_special=False
# Processing m=361, n=80, is_special=False
# Processing m=361, n=81, is_special=False
# Processing m=361, n=82, is_special=False
# Processing m=361, n=83, is_special=False
# Processing m=361, n=84, is_special=False
# Processing m=361, n=85, is_special=False
# Processing m=361, n=86, is_special=False
# Processing m=361, n=87, is_special=False
# Processing m=361, n=88, is_special=False
# Processing m=361, n=89, is_special=False
# Processing m=361, n=90, is_special=False
# Processing m=362, n=0, is_special=False
# Processing m=362, n=1, is_special=False
# Processing m=362, n=2, is_special=False
# Processing m=362, n=3, is_special=False
# Processing m=362, n=4, is_special=False
# Processing m=362, n=5, is_special=False
# Processing m=362, n=6, is_special=False
# Processing m=362, n=7, is_special=False
# Processing m=362, n=8, is_special=False
# Processing m=362, n=9, is_special=False
# Processing m=362, n=10, is_special=False
# Processing m=362, n=11, is_special=False
# Processing m=362, n=12, is_special=False
# Processing m=362, n=13, is_special=False
# Processing m=362, n=14, is_special=False
# Processing m=362, n=15, is_special=False
# Processing m=362, n=16, is_special=False
# Processing m=362, n=17, is_special=False
# Processing m=362, n=18, is_special=False
# Processing m=362, n=19, is_special=False
# Processing m=362, n=20, is_special=False
# Processing m=362, n=21, is_special=False
# Processing m=362, n=22, is_special=False
# Processing m=362, n=23, is_special=False
# Processing m=362, n=24, is_special=False
# Processing m=362, n=25, is_special=False
# Processing m=362, n=26, is_special=False
# Processing m=362, n=27, is_special=False
# Processing m=362, n=28, is_special=False
# Processing m=362, n=29, is_special=False
# Processing m=362, n=30, is_special=False
# Processing m=362, n=31, is_special=False
# Processing m=362, n=32, is_special=False
# Processing m=362, n=33, is_special=False
# Processing m=362, n=34, is_special=False
# Processing m=362, n=35, is_special=False
# Processing m=362, n=36, is_special=False
# Processing m=362, n=37, is_special=False
# Processing m=362, n=38, is_special=False
# Processing m=362, n=39, is_special=False
# Processing m=362, n=40, is_special=False
# Processing m=362, n=41, is_special=False
# Processing m=362, n=42, is_special=False
# Processing m=362, n=43, is_special=False
# Processing m=362, n=44, is_special=False
# Processing m=362, n=45, is_special=False
# Processing m=362, n=46, is_special=False
# Processing m=362, n=47, is_special=False
# Processing m=362, n=48, is_special=False
# Processing m=362, n=49, is_special=False
# Processing m=362, n=50, is_special=False
# Processing m=362, n=51, is_special=False
# Processing m=362, n=52, is_special=False
# Processing m=362, n=53, is_special=False
# Processing m=362, n=54, is_special=False
# Processing m=362, n=55, is_special=False
# Processing m=362, n=56, is_special=False
# Processing m=362, n=57, is_special=False
# Processing m=362, n=58, is_special=False
# Processing m=362, n=59, is_special=False
# Processing m=362, n=60, is_special=False
# Processing m=362, n=61, is_special=False
# Processing m=362, n=62, is_special=False
# Processing m=362, n=63, is_special=False
# Processing m=362, n=64, is_special=False
# Processing m=362, n=65, is_special=False
# Processing m=362, n=66, is_special=False
# Processing m=362, n=67, is_special=False
# Processing m=362, n=68, is_special=False
# Processing m=362, n=69, is_special=False
# Processing m=362, n=70, is_special=False
# Processing m=362, n=71, is_special=False
# Processing m=362, n=72, is_special=False
# Processing m=362, n=73, is_special=False
# Processing m=362, n=74, is_special=False
# Processing m=362, n=75, is_special=False
# Processing m=362, n=76, is_special=False
# Processing m=362, n=77, is_special=False
# Processing m=362, n=78, is_special=False
# Processing m=362, n=79, is_special=False
# Processing m=362, n=80, is_special=False
# Processing m=362, n=81, is_special=False
# Processing m=362, n=82, is_special=False
# Processing m=362, n=83, is_special=False
# Processing m=362, n=84, is_special=False
# Processing m=362, n=85, is_special=False
# Processing m=362, n=86, is_special=False
# Processing m=362, n=87, is_special=False
# Processing m=362, n=88, is_special=False
# Processing m=362, n=89, is_special=False
# Processing m=362, n=90, is_special=False
# Processing m=363, n=0, is_special=False
# Processing m=363, n=1, is_special=False
# Processing m=363, n=2, is_special=False
# Processing m=363, n=3, is_special=False
# Processing m=363, n=4, is_special=False
# Processing m=363, n=5, is_special=False
# Processing m=363, n=6, is_special=False
# Processing m=363, n=7, is_special=False
# Processing m=363, n=8, is_special=False
# Processing m=363, n=9, is_special=False
# Processing m=363, n=10, is_special=False
# Processing m=363, n=11, is_special=False
# Processing m=363, n=12, is_special=False
# Processing m=363, n=13, is_special=False
# Processing m=363, n=14, is_special=False
# Processing m=363, n=15, is_special=False
# Processing m=363, n=16, is_special=False
# Processing m=363, n=17, is_special=False
# Processing m=363, n=18, is_special=False
# Processing m=363, n=19, is_special=False
# Processing m=363, n=20, is_special=False
# Processing m=363, n=21, is_special=False
# Processing m=363, n=22, is_special=False
# Processing m=363, n=23, is_special=False
# Processing m=363, n=24, is_special=False
# Processing m=363, n=25, is_special=False
# Processing m=363, n=26, is_special=False
# Processing m=363, n=27, is_special=False
# Processing m=363, n=28, is_special=False
# Processing m=363, n=29, is_special=False
# Processing m=363, n=30, is_special=False
# Processing m=363, n=31, is_special=False
# Processing m=363, n=32, is_special=False
# Processing m=363, n=33, is_special=False
# Processing m=363, n=34, is_special=False
# Processing m=363, n=35, is_special=False
# Processing m=363, n=36, is_special=False
# Processing m=363, n=37, is_special=False
# Processing m=363, n=38, is_special=False
# Processing m=363, n=39, is_special=False
# Processing m=363, n=40, is_special=False
# Processing m=363, n=41, is_special=False
# Processing m=363, n=42, is_special=False
# Processing m=363, n=43, is_special=False
# Processing m=363, n=44, is_special=False
# Processing m=363, n=45, is_special=False
# Processing m=363, n=46, is_special=False
# Processing m=363, n=47, is_special=False
# Processing m=363, n=48, is_special=False
# Processing m=363, n=49, is_special=False
# Processing m=363, n=50, is_special=False
# Processing m=363, n=51, is_special=False
# Processing m=363, n=52, is_special=False
# Processing m=363, n=53, is_special=False
# Processing m=363, n=54, is_special=False
# Processing m=363, n=55, is_special=False
# Processing m=363, n=56, is_special=False
# Processing m=363, n=57, is_special=False
# Processing m=363, n=58, is_special=False
# Processing m=363, n=59, is_special=False
# Processing m=363, n=60, is_special=False
# Processing m=363, n=61, is_special=False
# Processing m=363, n=62, is_special=False
# Processing m=363, n=63, is_special=False
# Processing m=363, n=64, is_special=False
# Processing m=363, n=65, is_special=False
# Processing m=363, n=66, is_special=False
# Processing m=363, n=67, is_special=False
# Processing m=363, n=68, is_special=False
# Processing m=363, n=69, is_special=False
# Processing m=363, n=70, is_special=False
# Processing m=363, n=71, is_special=False
# Processing m=363, n=72, is_special=False
# Processing m=363, n=73, is_special=False
# Processing m=363, n=74, is_special=False
# Processing m=363, n=75, is_special=False
# Processing m=363, n=76, is_special=False
# Processing m=363, n=77, is_special=False
# Processing m=363, n=78, is_special=False
# Processing m=363, n=79, is_special=False
# Processing m=363, n=80, is_special=False
# Processing m=363, n=81, is_special=False
# Processing m=363, n=82, is_special=False
# Processing m=363, n=83, is_special=False
# Processing m=363, n=84, is_special=False
# Processing m=363, n=85, is_special=False
# Processing m=363, n=86, is_special=False
# Processing m=363, n=87, is_special=False
# Processing m=363, n=88, is_special=False
# Processing m=363, n=89, is_special=False
# Processing m=363, n=90, is_special=False

# %%
simulator = circuit.simulator(temperature=25, nominal_temperature=25)
# %time analysis = simulator.dc(V1=slice(0, 2, 0.001))
voltage = analysis.nodes['input'].as_ndarray()  # analysis: a dictionary of measured values from nodes and branches
current = analysis.branches['v1'].as_ndarray()  # as_ndarray: converts measured values from a specific node or branch into a numpy array
normalized_current = current / (w * l * M *N)

# Calculate open circuit voltage
v_oc_index = np.argmin(np.abs(normalized_current))  # abs: function that returns the absolute value of a given number
v_oc = voltage[v_oc_index]  # argmin: returns the index of the minimum element in the numpy array

# Calculate short circuit current
i_sc_index = np.argmin(np.abs(voltage))
i_sc = normalized_current[i_sc_index]

# Calculate Maximum Power Point
power = voltage * current
mpp_index = np.argmax(power)
v_mpp = voltage[mpp_index]
i_mpp = normalized_current[mpp_index]
max_power = power[mpp_index]
efficiency = (max_power/(0.1*w*l*M*N))*100

# Calculate Fill Factor
fill_factor = (v_mpp * i_mpp) / (v_oc * i_sc)

plt.plot(voltage, normalized_current)

plt.legend()
plt.xlabel('Voltage (V)')
plt.ylabel('Current Density (A/cm²)')
plt.title('IV Curve for Different Number of Pairs')

# 오픈 회로 전압과 단락 전류 표시
plt.plot(v_oc, 0, 'ro', label=f'Open Circuit Voltage ({v_oc:.5f} V)')
plt.plot(0, i_sc, 'bo', label=f'Short Circuit Current ({i_sc:.5f} A)')
plt.plot(0, -0.025, label=f'Fill Factor ({fill_factor*100:.2f} %)')
plt.plot(0, -0.02, label=f'Efficiency ({efficiency:.2f} %)')
# 최대 전력 지점 표시
plt.plot(v_mpp, i_mpp, 'go', label=f'Maximum Power Point ({v_mpp:.5f} V, {i_mpp:.5f} A, {max_power:.5f} W)')

plt.legend()

plt.show()
# Out:
# CPU times: total: 1h 29min 49s
# Wall time: 2h 16min 30s
# 2023-08-30 14:56:37,034 - matplotlib.legend - legend.WARNING - No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
