# %%
import matplotlib.pyplot as plt
plt.rcParams['axes.titlesize'] = 30
plt.rcParams['axes.labelsize'] = 30
plt.rcParams['xtick.labelsize'] = 25
plt.rcParams['ytick.labelsize'] = 25
plt.rcParams['legend.fontsize'] = 25

x_data =[0.5, 1, 1.5, 2]


y_data1 = [1.917, 1.917, 1.917, 1.917]
y_data2 = [19.27, 19.21, 19.14, 19.07]
y_data3 = [83.45, 83.45, 83.49, 83.53]
y_data4 = [30.83, 30.73, 30.64, 30.54]

y_data5 = [1.917, 1.917, 1.917, 1.917]
y_data6 = [19.26, 19.19, 19.12, 19.05]
y_data7 = [83.49, 83.52, 83.55, 83.6]
y_data8 = [30.82, 30.72, 30.63, 30.53]

y_data9 = [1.917, 1.917, 1.917, 1.917]
y_data10 = [19.25, 19.18, 19.11, 19.04]
y_data11 = [83.51, 83.54, 83.58, 83.62]
y_data12 = [30.82, 30.72, 30.62, 30.52]

y_data13 = [1.917, 1.917, 1.917, 1.917]
y_data14 = [19.25, 19.18, 19.1, 19.02]
y_data15 = [83.51, 83.55, 83.6, 83.64]
y_data16 = [30.82, 30.72, 30.61, 30.5]


# Figure 1
plt.figure(figsize=(15, 10))
plt.plot(x_data, y_data1, 'o-', linewidth=5, markersize=20,label='25um*25um Size Cluster')
plt.plot(x_data, y_data5, 'o-', linewidth=5, markersize=20,label='50um*50um Size Cluster')
plt.plot(x_data, y_data9, 'o-', linewidth=5, markersize=20,label='75um*75um Size Cluster')
plt.plot(x_data, y_data13, 'o-', linewidth=5, markersize=20,label='100um*100um Size Cluster')
plt.xlabel('Area Fraction of Open Defects(%)', fontsize=30)
plt.ylabel('Voc (V)', fontsize=30)
plt.legend(fontsize=20)
plt.grid(True)
# 저장하기 전 삭제된 일부분 없이 전체 그림이 잘 저장되도록 조정
plt.savefig("Voc.png", dpi=300, bbox_inches='tight')
plt.show()  # 이 그래프를 보여주고 새 창에서 다음 그래프 시작


# Figure 2
plt.figure(figsize=(15, 10))
plt.plot(x_data, y_data2, 'o-', linewidth=5, markersize=20,label='25um*25um Size Cluster')
plt.plot(x_data, y_data6, 'o-', linewidth=5, markersize=20,label='50um*50um Size Cluster')
plt.plot(x_data, y_data10, 'o-', linewidth=5, markersize=20,label='75um*75um Size Cluster')
plt.plot(x_data, y_data14, 'o-', linewidth=5, markersize=20,label='100um*100um Size Cluster')
plt.xlabel('Area Fraction of Open Defects(%)', fontsize=30)
plt.ylabel('Isc (mA/cm²)', fontsize=30)
plt.legend(fontsize=20)
plt.grid(True)
# 저장하기 전 삭제된 일부분 없이 전체 그림이 잘 저장되도록 조정
plt.savefig("Isc.png", dpi=300, bbox_inches='tight')
plt.show()  # 이 그래프를 보여주고 새 창에서 다음 그래프 시작


# Figure 3
plt.figure(figsize=(15, 10))
plt.plot(x_data, y_data3,'o-', linewidth=5, markersize=20,label='25um*25um Size Cluster')
plt.plot(x_data, y_data7, 'o-', linewidth=5, markersize=20,label='50um*50um Size Cluster')
plt.plot(x_data, y_data11, 'o-', linewidth=5, markersize=20,label='75um*75um Size Cluster')
plt.plot(x_data, y_data15, 'o-', linewidth=5, markersize=20,label='100um*100um Size Cluster')
plt.xlabel('Area Fraction of Open Defects(%)', fontsize=30)
plt.ylabel('FF (%)', fontsize=30)
plt.legend(fontsize=20)
plt.grid(True)
# 저장하기 전 삭제된 일부분 없이 전체 그림이 잘 저장되도록 조정
plt.savefig("FF.png", dpi=300, bbox_inches='tight')
plt.show()  # 이 그래프를 보여주고 새 창에서 다음 그래프 시작


# Figure 4
plt.figure(figsize=(15, 10))
plt.plot(x_data, y_data4, 'o-', linewidth=5, markersize=20,label='25um*25um Size Cluster')
plt.plot(x_data, y_data8, 'o-', linewidth=5, markersize=20,label='50um*50um Size Cluster')
plt.plot(x_data, y_data12, 'o-', linewidth=5, markersize=20,label='75um*75um Size Cluster')
plt.plot(x_data, y_data16, 'o-', linewidth=5, markersize=20,label='100um*100um Size Cluster')
plt.xlabel('Area Fraction of Open Defects(%)', fontsize=30)
plt.ylabel('PCE (%)', fontsize=30)
plt.legend(fontsize=20)
plt.grid(True)
# 저장하기 전 삭제된 일부분 없이 전체 그림이 잘 저장되도록 조정
plt.savefig("PCE.png", dpi=300, bbox_inches='tight')
plt.show()  # 이 그래프를 보여주고 새 창에서 다음 그래프 시작


plt.tight_layout()  # 그래프 간의 간격을 자동으로 맞춰줍니다.
plt.show()
