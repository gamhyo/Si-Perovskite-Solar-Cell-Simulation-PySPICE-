# %%
import numpy as np
import matplotlib.pyplot as plt

# 불러올 파일의 경로 리스트
files = [
    r"C:\Users\jfkn5\OneDrive - 한양대학교\바탕 화면\Jeon Gamhyo\Solar Cell Simulation by PySpice\Data for Paper\Open Fraction\0.txt",
    r"C:\Users\jfkn5\OneDrive - 한양대학교\바탕 화면\Jeon Gamhyo\Solar Cell Simulation by PySpice\Data for Paper\Open Fraction\0.25.txt",
    r"C:\Users\jfkn5\OneDrive - 한양대학교\바탕 화면\Jeon Gamhyo\Solar Cell Simulation by PySpice\Data for Paper\Open Fraction\0.5.txt",
    r"C:\Users\jfkn5\OneDrive - 한양대학교\바탕 화면\Jeon Gamhyo\Solar Cell Simulation by PySpice\Data for Paper\Open Fraction\0.75.txt",
    r"C:\Users\jfkn5\OneDrive - 한양대학교\바탕 화면\Jeon Gamhyo\Solar Cell Simulation by PySpice\Data for Paper\Open Fraction\1.txt",
    r"C:\Users\jfkn5\OneDrive - 한양대학교\바탕 화면\Jeon Gamhyo\Solar Cell Simulation by PySpice\Data for Paper\Open Fraction\1.25.txt",
    r"C:\Users\jfkn5\OneDrive - 한양대학교\바탕 화면\Jeon Gamhyo\Solar Cell Simulation by PySpice\Data for Paper\Open Fraction\1.5.txt",
    r"C:\Users\jfkn5\OneDrive - 한양대학교\바탕 화면\Jeon Gamhyo\Solar Cell Simulation by PySpice\Data for Paper\Open Fraction\1.75.txt",
    r"C:\Users\jfkn5\OneDrive - 한양대학교\바탕 화면\Jeon Gamhyo\Solar Cell Simulation by PySpice\Data for Paper\Open Fraction\2.txt",
    
    # ... 다른 파일 경로 추가
]


# 각 파일을 반복문을 통해 읽어들임
for file_path in files:
    with open(file_path, 'r') as file:
        # 데이터를 1000으로 곱해 mV 단위로 전환
        data = [float(line.strip()) * 1000 for line in file]  # 데이터 값 변환
    
    # 시간 축 (예: 데이터 포인트 간의 간격이 1ms라고 가정)
    time = np.linspace(0, len(data) * 0.001, len(data))
    
    # 데이터를 그래프에 추가, 파일 이름만 라벨로 사용
    plt.plot(time, data, label=file_path.split('\\')[-1], linewidth = 0.5)  # 경로가 아닌, 파일 이름만 추출하여 라벨로 사용

# 그래프 설정
plt.xlabel('Applied Voltage (V)', fontsize = 20)
# y축 라벨 mA/cm²단위로 변경
plt.ylabel('Isc (mA/cm²)', fontsize = 20)

# 눈금 글씨 조절
plt.tick_params(axis='both', which='major', labelsize=20)

plt.grid()
# y축의 값에 맞게 변경 해야 할 수도 있음
plt.ylim(0, 20)  # 예시로 수정한 값, 실제 데이터에 맞게 조정 필요

# 그래프를 이미지 파일로 저장, dpi로 해상도 지정 가능
plt.savefig("Open fraction trends1.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 불러올 파일의 경로 리스트
files = [
    r"C:\Users\jfkn5\OneDrive - 한양대학교\바탕 화면\Jeon Gamhyo\Solar Cell Simulation by PySpice\Data for Paper\Open Fraction\0.txt",
    r"C:\Users\jfkn5\OneDrive - 한양대학교\바탕 화면\Jeon Gamhyo\Solar Cell Simulation by PySpice\Data for Paper\Open Fraction\0.25.txt",
    r"C:\Users\jfkn5\OneDrive - 한양대학교\바탕 화면\Jeon Gamhyo\Solar Cell Simulation by PySpice\Data for Paper\Open Fraction\0.5.txt",
    r"C:\Users\jfkn5\OneDrive - 한양대학교\바탕 화면\Jeon Gamhyo\Solar Cell Simulation by PySpice\Data for Paper\Open Fraction\0.75.txt",
    r"C:\Users\jfkn5\OneDrive - 한양대학교\바탕 화면\Jeon Gamhyo\Solar Cell Simulation by PySpice\Data for Paper\Open Fraction\1.txt",
    r"C:\Users\jfkn5\OneDrive - 한양대학교\바탕 화면\Jeon Gamhyo\Solar Cell Simulation by PySpice\Data for Paper\Open Fraction\1.25.txt",
    r"C:\Users\jfkn5\OneDrive - 한양대학교\바탕 화면\Jeon Gamhyo\Solar Cell Simulation by PySpice\Data for Paper\Open Fraction\1.5.txt",
    r"C:\Users\jfkn5\OneDrive - 한양대학교\바탕 화면\Jeon Gamhyo\Solar Cell Simulation by PySpice\Data for Paper\Open Fraction\1.75.txt",
    r"C:\Users\jfkn5\OneDrive - 한양대학교\바탕 화면\Jeon Gamhyo\Solar Cell Simulation by PySpice\Data for Paper\Open Fraction\2.txt",
    
    # ... 다른 파일 경로 추가
]


# 각 파일을 반복문을 통해 읽어들임
for file_path in files:
    with open(file_path, 'r') as file:
        # 데이터를 1000으로 곱해 mV 단위로 전환
        data = [float(line.strip()) * 1000 for line in file]  # 데이터 값 변환
    
    # 시간 축 (예: 데이터 포인트 간의 간격이 1ms라고 가정)
    time = np.linspace(0, len(data) * 0.001, len(data))
    
    # 데이터를 그래프에 추가, 파일 이름만 라벨로 사용
    plt.plot(time, data, label=file_path.split('\\')[-1], linewidth = 3)  # 경로가 아닌, 파일 이름만 추출하여 라벨로 사용



# 눈금 글씨 조절
plt.tick_params(axis='both', which='major', labelsize=20)

plt.grid()
plt.ylim(17.5, 20)

# 그래프를 이미지 파일로 저장, dpi로 해상도 지정 가능
plt.savefig("Open fraction trends2.png", dpi=600, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['axes.titlesize'] = 20  # 제목
plt.rcParams['axes.labelsize'] = 15  # 축 이름
plt.rcParams['xtick.labelsize'] = 13  # x축 눈금
plt.rcParams['ytick.labelsize'] = 13  # y축 눈금
plt.rcParams['legend.fontsize'] = 13  # 범례

x_data =[0, 0.25, 0.5, 0.75, 1, 1.25, 1.5, 1.75, 2]


y_data1 = [1.917, 1.917, 1.917, 1.917, 1.917, 1.917, 1.917, 1.917, 1.917]
y_data2 = [19.32, 19.3, 19.26, 19.23, 19.19, 19.15, 19.11, 19.07, 19.03]
y_data3 = [83.47, 83.45, 83.44, 83.45, 83.46, 83.47, 83.5, 83.53, 83.55]
y_data4 = [30.92, 30.87, 30.81, 30.76, 30.71, 30.65, 30.59, 30.53, 30.48]

plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
plt.plot(x_data, y_data1, 'o-r')  # 빨간색
plt.xlabel('Opened fraction(%)')
plt.ylabel('V_oc(V)')
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(x_data, y_data2, 'o-b')  # 파란색
plt.xlabel('Opened fraction(%)')
plt.ylabel('Current Density(mA/cm²)')
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(x_data, y_data3, 'o-g')  # 초록색
plt.xlabel('Opened fraction(%)')
plt.ylabel('Fill Factor(%)')
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(x_data, y_data4, 'o-c')  # 청록색
plt.xlabel('Opened fraction(%)')
plt.ylabel('Power Conversion Efficiency(%)')
plt.grid(True)

plt.tight_layout()  
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['axes.titlesize'] = 30 
plt.rcParams['axes.labelsize'] = 30  
plt.rcParams['xtick.labelsize'] = 25  
plt.rcParams['ytick.labelsize'] = 25 
plt.rcParams['legend.fontsize'] = 25 

x_data =[0, 0.25, 0.5, 0.75, 1, 1.25, 1.5, 1.75, 2]

y_data1 = [1.917, 1.917, 1.917, 1.917, 1.917, 1.917, 1.917, 1.917, 1.917]
y_data2 = [19.32, 19.3, 19.26, 19.23, 19.19, 19.15, 19.11, 19.07, 19.03]
y_data3 = [83.47, 83.45, 83.44, 83.45, 83.46, 83.47, 83.5, 83.53, 83.55]
y_data4 = [30.92, 30.87, 30.81, 30.76, 30.71, 30.65, 30.59, 30.53, 30.48]

fig, ax1 = plt.subplots(figsize=(20, 15))

color = 'tab:red'
ax1.set_xlabel('Area Fraction of Open Defects(%)', fontsize=30, fontweight='bold')
ax1.set_ylabel('V_oc(V)', color=color, fontsize=25, fontweight='bold')
ax1.plot(x_data, y_data1, 'o-r')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Current Density(mA/cm²)', color=color, fontsize=25, fontweight='bold')
ax2.plot(x_data, y_data2, 'o-b')
ax2.tick_params(axis='y', labelcolor=color)

ax3 = ax1.twinx()
color = 'tab:green'
ax3.spines['right'].set_position(('outward', 80))  
ax3.set_ylabel('Fill Factor(%)', color=color, fontsize=25, fontweight='bold')
ax3.plot(x_data, y_data3, 'o-g')
ax3.tick_params(axis='y', labelcolor=color)

ax4 = ax1.twinx()
color = 'tab:cyan'
ax4.spines['right'].set_position(('outward', 160))  
ax4.set_ylabel('Power Conversion Efficiency(%)', color=color, fontsize=25, fontweight='bold')
ax4.plot(x_data, y_data4, 'o-c')
ax4.tick_params(axis='y', labelcolor=color)

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['axes.titlesize'] = 30
plt.rcParams['axes.labelsize'] = 30
plt.rcParams['xtick.labelsize'] = 25
plt.rcParams['ytick.labelsize'] = 25
plt.rcParams['legend.fontsize'] = 25

x_data =[0, 0.25, 0.5, 0.75, 1, 1.25, 1.5, 1.75, 2]
y_data1 = [1.917, 1.917, 1.917, 1.917, 1.917, 1.917, 1.917, 1.917, 1.917]
y_data2 = [19.32, 19.3, 19.26, 19.23, 19.19, 19.15, 19.11, 19.07, 19.03]
y_data3 = [83.47, 83.45, 83.44, 83.45, 83.46, 83.47, 83.5, 83.53, 83.55]
y_data4 = [30.92, 30.87, 30.81, 30.76, 30.71, 30.65, 30.59, 30.53, 30.48]

fig, ax1 = plt.subplots(figsize=(20, 15))

color = 'tab:red'
ax1.set_xlabel('Area Fraction of Open Defects(%)', fontweight='bold')
ax1.set_ylabel('V_oc(V)', color=color, fontweight='bold')
ax1.plot(x_data, y_data1, 'o-r', linewidth=5, markersize=20)  # 여기를 수정
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Current Density(mA/cm²)', color=color, fontweight='bold')
ax2.plot(x_data, y_data2, 'o-b', linewidth=5, markersize=20)  # 여기를 수정
ax2.tick_params(axis='y', labelcolor=color)

ax3 = ax1.twinx()
color = 'tab:green'
ax3.spines['right'].set_position(('outward', 120))
ax3.set_ylabel('Fill Factor(%)', color=color, fontweight='bold')
ax3.plot(x_data, y_data3, 'o-g', linewidth=5, markersize=20)  # 여기를 수정
ax3.tick_params(axis='y', labelcolor=color)

ax4 = ax1.twinx()
color = 'tab:cyan'
ax4.spines['right'].set_position(('outward', 240))
ax4.set_ylabel('Power Conversion Efficiency(%)', color=color, fontweight='bold')
ax4.plot(x_data, y_data4, 'o-c', linewidth=5, markersize=20)  # 여기를 수정
ax4.tick_params(axis='y', labelcolor=color)

fig.tight_layout()
plt.show()
