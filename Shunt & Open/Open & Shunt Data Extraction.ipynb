# %%
# 1% Open
import numpy as np
import matplotlib.pyplot as plt

# 불러올 파일의 경로 리스트
files = [
    
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\0.25.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\0.5.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\0.75.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\1.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\1.25.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\1.5.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\1.75.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\2.txt",
    
    # ... 다른 파일 경로 추가
]


# 각 파일을 반복문을 통해 읽어들임
for file_path in files:
    with open(file_path, 'r') as file:
        data = [float(line.strip()) for line in file]
    
    # 시간 축 (예: 데이터 포인트 간의 간격이 1ms라고 가정)
    time = np.linspace(0, len(data) * 0.001, len(data))
    
    # 데이터를 그래프에 추가
    plt.plot(time, data, label=file_path)  # label을 사용하여 각 데이터의 범례를 추가

# 그래프 설정
plt.xlabel('Voltage(V)')
plt.ylabel('Current Density(A/cm²)')
plt.grid(True)
plt.ylim(0, 0.02)
plt.show()

# %%
# 1% Open
import numpy as np
import matplotlib.pyplot as plt

# 불러올 파일의 경로 리스트
files = [
    
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\0.25.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\0.5.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\0.75.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\1.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\1.25.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\1.5.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\1.75.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\2.txt",
    
    # ... 다른 파일 경로 추가
]


# 각 파일을 반복문을 통해 읽어들임
for file_path in files:
    with open(file_path, 'r') as file:
        data = [float(line.strip()) for line in file]
    
    # 시간 축 (예: 데이터 포인트 간의 간격이 1ms라고 가정)
    time = np.linspace(0, len(data) * 0.001, len(data))
    
    # 데이터를 그래프에 추가
    plt.plot(time, data, label=file_path)  # label을 사용하여 각 데이터의 범례를 추가

# 그래프 설정
plt.xlabel('Voltage(V)')
plt.ylabel('Current Density(A/cm²)')
plt.grid(True)
plt.xlim(0, 0.6)
plt.ylim(0.019, 0.02)
plt.show()

# %%
# 1% Open
import matplotlib.pyplot as plt
plt.rcParams['axes.titlesize'] = 20  # 제목
plt.rcParams['axes.labelsize'] = 15  # 축 이름
plt.rcParams['xtick.labelsize'] = 13  # x축 눈금
plt.rcParams['ytick.labelsize'] = 13  # y축 눈금
plt.rcParams['legend.fontsize'] = 13  # 범례

x_data =[0.25, 0.5, 0.75, 1, 1.25, 1.5, 1.75, 2]


y_data1 = [1.915, 1.912, 1.909, 1.906, 1.904, 1.901, 1.898, 1.895]
y_data2 = [19.22, 19.24, 19.25, 19.26, 19.28, 19.29, 19.29, 19.29]
y_data3 = [83.83, 78.34, 75.61, 73.1, 70.39, 67.76, 65.13, 62.52]
y_data4 = [29.75, 28.82, 27.78, 26.84, 25.85, 24.85, 23.85, 22.86]

plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
plt.plot(x_data, y_data1, 'o-r')  # 빨간색
plt.xlabel('Opened fraction(%)')
plt.ylabel('V_oc(V)')
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(x_data, y_data2, 'o-b')  # 파란색
plt.xlabel('Opened fraction(%)')
plt.ylabel('Current Density(mA/cm²)')
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(x_data, y_data3, 'o-g')  # 초록색
plt.xlabel('Opened fraction(%)')
plt.ylabel('Fill Factor(%)')
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(x_data, y_data4, 'o-c')  # 청록색
plt.xlabel('Opened fraction(%)')
plt.ylabel('Power Conversion Efficiency(%)')
plt.grid(True)

plt.tight_layout()  
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['axes.titlesize'] = 20  
plt.rcParams['axes.labelsize'] = 15  
plt.rcParams['xtick.labelsize'] = 13  
plt.rcParams['ytick.labelsize'] = 13  
plt.rcParams['legend.fontsize'] = 13  

x_data =[0.25, 0.5, 0.75, 1, 1.25, 1.5, 1.75, 2]


y_data1 = [1.915, 1.912, 1.909, 1.906, 1.904, 1.901, 1.898, 1.895]
y_data2 = [19.22, 19.24, 19.25, 19.26, 19.28, 19.29, 19.29, 19.29]
y_data3 = [83.83, 78.34, 75.61, 73.1, 70.39, 67.76, 65.13, 62.52]
y_data4 = [29.75, 28.82, 27.78, 26.84, 25.85, 24.85, 23.85, 22.86]

fig, ax1 = plt.subplots(figsize=(15, 10))

color = 'tab:red'
ax1.set_xlabel('Shunted fraction(%)')
ax1.set_ylabel('V_oc(V)', color=color)
ax1.plot(x_data, y_data1, 'o-r')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Current Density(mA/cm²)', color=color)
ax2.plot(x_data, y_data2, 'o-b')
ax2.tick_params(axis='y', labelcolor=color)

ax3 = ax1.twinx()
color = 'tab:green'
ax3.spines['right'].set_position(('outward', 80))  
ax3.set_ylabel('Fill Factor(%)', color=color)
ax3.plot(x_data, y_data3, 'o-g')
ax3.tick_params(axis='y', labelcolor=color)

ax4 = ax1.twinx()
color = 'tab:cyan'
ax4.spines['right'].set_position(('outward', 160))  
ax4.set_ylabel('Power Conversion Efficiency(%)', color=color)
ax4.plot(x_data, y_data4, 'o-c')
ax4.tick_params(axis='y', labelcolor=color)

fig.tight_layout()
plt.show()

# %%
# 2% Open
import numpy as np
import matplotlib.pyplot as plt

# 불러올 파일의 경로 리스트
files = [
    
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\0.25'.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\0.5'.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\0.75'.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\1'.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\1.25'.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\1.5'.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\1.75'.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\2'.txt",
    
    # ... 다른 파일 경로 추가
]


# 각 파일을 반복문을 통해 읽어들임
for file_path in files:
    with open(file_path, 'r') as file:
        data = [float(line.strip()) for line in file]
    
    # 시간 축 (예: 데이터 포인트 간의 간격이 1ms라고 가정)
    time = np.linspace(0, len(data) * 0.001, len(data))
    
    # 데이터를 그래프에 추가
    plt.plot(time, data, label=file_path)  # label을 사용하여 각 데이터의 범례를 추가

# 그래프 설정
plt.xlabel('Voltage(V)')
plt.ylabel('Current Density(A/cm²)')
plt.grid(True)
plt.xlim(0, 0.6)
plt.ylim(0.01875, 0.02)
plt.show()

# %%
# 2% Open
import numpy as np
import matplotlib.pyplot as plt

# 불러올 파일의 경로 리스트
files = [
    
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\0.25'.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\0.5'.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\0.75'.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\1'.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\1.25'.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\1.5'.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\1.75'.txt",
    r"C:\Users\User\Desktop\Solar Cell Simulation by PySpice\Data for Paper\Shunt & Open\2'.txt",
    
    # ... 다른 파일 경로 추가
]


# 각 파일을 반복문을 통해 읽어들임
for file_path in files:
    with open(file_path, 'r') as file:
        data = [float(line.strip()) for line in file]
    
    # 시간 축 (예: 데이터 포인트 간의 간격이 1ms라고 가정)
    time = np.linspace(0, len(data) * 0.001, len(data))
    
    # 데이터를 그래프에 추가
    plt.plot(time, data, label=file_path)  # label을 사용하여 각 데이터의 범례를 추가

# 그래프 설정
plt.xlabel('Voltage(V)')
plt.ylabel('Current Density(A/cm²)')
plt.grid(True)
plt.ylim(0, 0.02)
plt.show()

# %%
# 2% Open
import matplotlib.pyplot as plt
plt.rcParams['axes.titlesize'] = 20  # 제목
plt.rcParams['axes.labelsize'] = 15  # 축 이름
plt.rcParams['xtick.labelsize'] = 13  # x축 눈금
plt.rcParams['ytick.labelsize'] = 13  # y축 눈금
plt.rcParams['legend.fontsize'] = 13  # 범례

x_data =[0.25, 0.5, 0.75, 1, 1.25, 1.5, 1.75, 2]


y_data1 = [1.915, 1.912, 1.909, 1.906, 1.904, 1.9, 1.898, 1.895]
y_data2 = [19.09, 19.14, 19.18, 19.18, 19.23, 19.24, 19.26, 19.27]
y_data3 = [80.74, 77.95, 75.28, 72.67, 69.81, 67.16, 64.69, 62.08]
y_data4 = [29.52, 28.52, 27.56, 26.57, 25.57, 24.55, 23.64, 22.67]

plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
plt.plot(x_data, y_data1, 'o-r')  # 빨간색
plt.xlabel('Opened fraction(%)')
plt.ylabel('V_oc(V)')
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(x_data, y_data2, 'o-b')  # 파란색
plt.xlabel('Opened fraction(%)')
plt.ylabel('Current Density(mA/cm²)')
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(x_data, y_data3, 'o-g')  # 초록색
plt.xlabel('Opened fraction(%)')
plt.ylabel('Fill Factor(%)')
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(x_data, y_data4, 'o-c')  # 청록색
plt.xlabel('Opened fraction(%)')
plt.ylabel('Power Conversion Efficiency(%)')
plt.grid(True)

plt.tight_layout()  
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['axes.titlesize'] = 30 
plt.rcParams['axes.labelsize'] = 20 
plt.rcParams['xtick.labelsize'] = 13  
plt.rcParams['ytick.labelsize'] = 13  
plt.rcParams['legend.fontsize'] = 13  

x_data =[0.25, 0.5, 0.75, 1, 1.25, 1.5, 1.75, 2]


y_data1 = [1.915, 1.912, 1.909, 1.906, 1.904, 1.9, 1.898, 1.895]
y_data2 = [19.09, 19.14, 19.18, 19.18, 19.23, 19.24, 19.26, 19.27]
y_data3 = [80.74, 77.95, 75.28, 72.67, 69.81, 67.16, 64.69, 62.08]
y_data4 = [29.52, 28.52, 27.56, 26.57, 25.57, 24.55, 23.64, 22.67]


fig, ax1 = plt.subplots(figsize=(15, 10))

color = 'tab:red'
ax1.set_xlabel('Shunted fraction(%)')
ax1.set_ylabel('V_oc(V)', color=color)
ax1.plot(x_data, y_data1, 'o-r')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Current Density(mA/cm²)', color=color)
ax2.plot(x_data, y_data2, 'o-b')
ax2.tick_params(axis='y', labelcolor=color)

ax3 = ax1.twinx()
color = 'tab:green'
ax3.spines['right'].set_position(('outward', 80))  
ax3.set_ylabel('Fill Factor(%)', color=color)
ax3.plot(x_data, y_data3, 'o-g')
ax3.tick_params(axis='y', labelcolor=color)

ax4 = ax1.twinx()
color = 'tab:cyan'
ax4.spines['right'].set_position(('outward', 160))  
ax4.set_ylabel('Power Conversion Efficiency(%)', color=color)
ax4.plot(x_data, y_data4, 'o-c')
ax4.tick_params(axis='y', labelcolor=color)

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['axes.titlesize'] = 30
plt.rcParams['axes.labelsize'] = 30
plt.rcParams['xtick.labelsize'] = 25
plt.rcParams['ytick.labelsize'] = 25
plt.rcParams['legend.fontsize'] = 25

x_data =[0.25, 0.5, 0.75, 1, 1.25, 1.5, 1.75, 2]


y_data1 = [1.915, 1.912, 1.909, 1.906, 1.904, 1.901, 1.898, 1.895]
y_data2 = [19.22, 19.24, 19.25, 19.26, 19.28, 19.29, 19.29, 19.29]
y_data3 = [83.83, 78.34, 75.61, 73.1, 70.39, 67.76, 65.13, 62.52]
y_data4 = [29.75, 28.82, 27.78, 26.84, 25.85, 24.85, 23.85, 22.86]

y_data5 = [1.915, 1.912, 1.909, 1.906, 1.904, 1.9, 1.898, 1.895]
y_data6 = [19.09, 19.14, 19.18, 19.18, 19.23, 19.24, 19.26, 19.27]
y_data7 = [80.74, 77.95, 75.28, 72.67, 69.81, 67.16, 64.69, 62.08]
y_data8 = [29.52, 28.52, 27.56, 26.57, 25.57, 24.55, 23.64, 22.67]


plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
plt.plot(x_data, y_data1, 'o-', linewidth=5, markersize=20, label='1% Area Fraction of Open Defect')
plt.plot(x_data, y_data5, 'o-',  linewidth=5, markersize=20,label='2% Area Fraction of Open Defect')
plt.xlabel('Area Fraction of Shunt Defects(%)', fontsize=18, fontweight='bold')
plt.ylabel('V_oc(V)', fontsize=20, fontweight='bold')
plt.legend(fontsize=18)
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(x_data, y_data2, 'o-', linewidth=5, markersize=20, label='1% Area Fraction of Open Defect')
plt.plot(x_data, y_data6, 'o-', linewidth=5, markersize=20,label='2% Area Fraction of Open Defect')
plt.xlabel('Area Fraction of Shunt Defects(%)', fontsize=18, fontweight='bold')
plt.ylabel('Current Density(mA/cm²)', fontsize=20, fontweight='bold')
plt.legend(fontsize=18)
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(x_data, y_data3,'o-',  linewidth=5, markersize=20,label='1% Area Fraction of Open Defect')
plt.plot(x_data, y_data7, 'o-',  linewidth=5, markersize=20,label='2% Area Fraction of Open Defect')
plt.xlabel('Area Fraction of Shunt Defects(%)', fontsize=18, fontweight='bold')
plt.ylabel('Fill Factor(%)', fontsize=20, fontweight='bold')
plt.legend(fontsize=18)
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(x_data, y_data4, 'o-',  linewidth=5, markersize=20,label='1% Area Fraction of Open Defect')
plt.plot(x_data, y_data8, 'o-',  linewidth=5, markersize=20,label='2% Area Fraction of Open Defect')
plt.xlabel('Area Fraction of Shunt Defects(%)', fontsize=18, fontweight='bold')
plt.ylabel('Power Conversion Efficiency(%)', fontsize=20, fontweight='bold')
plt.legend(fontsize=18)
plt.grid(True)

plt.tight_layout()  # 그래프 간의 간격을 자동으로 맞춰줍니다.
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['axes.titlesize'] = 30
plt.rcParams['axes.labelsize'] = 30
plt.rcParams['xtick.labelsize'] = 25
plt.rcParams['ytick.labelsize'] = 25
plt.rcParams['legend.fontsize'] = 25

x_data = [0.25, 0.5, 0.75, 1, 1.25, 1.5, 1.75, 2]

y_data1 = [1.915, 1.912, 1.909, 1.906, 1.904, 1.901, 1.898, 1.895]
y_data2 = [19.22, 19.24, 19.25, 19.26, 19.28, 19.29, 19.29, 19.29]
y_data3 = [83.83, 78.34, 75.61, 73.1, 70.39, 67.76, 65.13, 62.52]
y_data4 = [29.75, 28.82, 27.78, 26.84, 25.85, 24.85, 23.85, 22.86]

y_data5 = [1.915, 1.912, 1.909, 1.906, 1.904, 1.9, 1.898, 1.895]
y_data6 = [19.09, 19.14, 19.18, 19.18, 19.23, 19.24, 19.26, 19.27]
y_data7 = [80.74, 77.95, 75.28, 72.67, 69.81, 67.16, 64.69, 62.08]
y_data8 = [29.52, 28.52, 27.56, 26.57, 25.57, 24.55, 23.64, 22.67]

# Figure 1
plt.figure(figsize=(15, 10))
plt.plot(x_data, y_data1, 'o-', linewidth=5, markersize=20, label='1% Area Fraction of Open Defect')
plt.plot(x_data, y_data5, 'o-', linewidth=5, markersize=20, label='2% Area Fraction of Open Defect')
plt.xlabel('Area Fraction of Shunt Defects(%)', fontsize=30)
plt.ylabel('Voc (V)', fontsize=30)
plt.legend(fontsize=20)
plt.grid(True)
# 저장하기 전 삭제된 일부분 없이 전체 그림이 잘 저장되도록 조정
plt.savefig("Voc.png", dpi=300, bbox_inches='tight')
plt.show()  # 이 그래프를 보여주고 새 창에서 다음 그래프 시작

# Figure 2
plt.figure(figsize=(15, 10))
plt.plot(x_data, y_data2, 'o-', linewidth=5, markersize=20, label='1% Area Fraction of Open Defect')
plt.plot(x_data, y_data6, 'o-', linewidth=5, markersize=20, label='2% Area Fraction of Open Defect')
plt.xlabel('Area Fraction of Shunt Defects(%)', fontsize=30)
plt.ylabel('Isc (mA/cm²)', fontsize=30)
plt.legend(fontsize=20)
plt.grid(True)
# 저장하기 전 삭제된 일부분 없이 전체 그림이 잘 저장되도록 조정
plt.savefig("Isc.png", dpi=300, bbox_inches='tight')
plt.show()

# Figure 3
plt.figure(figsize=(15, 10))
plt.plot(x_data, y_data3, 'o-', linewidth=5, markersize=20, label='1% Area Fraction of Open Defect')
plt.plot(x_data, y_data7, 'o-', linewidth=5, markersize=20, label='2% Area Fraction of Open Defect')
plt.xlabel('Area Fraction of Shunt Defects(%)', fontsize=30)
plt.ylabel('FF (%)', fontsize=30)
plt.legend(fontsize=20)
plt.grid(True)
# 저장하기 전 삭제된 일부분 없이 전체 그림이 잘 저장되도록 조정
plt.savefig("FF.png", dpi=300, bbox_inches='tight')
plt.show()

# Figure 4
plt.figure(figsize=(15, 10))
plt.plot(x_data, y_data4, 'o-', linewidth=5, markersize=20, label='1% Area Fraction of Open Defect')
plt.plot(x_data, y_data8, 'o-', linewidth=5, markersize=20, label='2% Area Fraction of Open Defect')
plt.xlabel('Area Fraction of Shunt Defects(%)', fontsize=30)
plt.ylabel('PCE (%)', fontsize=30)
plt.legend(fontsize=20)
plt.grid(True)
# 저장하기 전 삭제된 일부분 없이 전체 그림이 잘 저장되도록 조정
plt.savefig("PCE.png", dpi=300, bbox_inches='tight')
plt.show()
