# %%
import matplotlib.pyplot as plt
plt.rcParams['axes.titlesize'] = 20  # 제목
plt.rcParams['axes.labelsize'] = 15  # 축 이름
plt.rcParams['xtick.labelsize'] = 13  # x축 눈금
plt.rcParams['ytick.labelsize'] = 13  # y축 눈금
plt.rcParams['legend.fontsize'] = 13  # 범례

x_data =[1, 100, 1000, 10000, 100000, 1000000]


y_data1 = [1.915, 1.915, 1.914, 1.914, 1.914, 1.914]
y_data2 = [19.32, 19.32, 19.32, 19.32, 19.32, 19.32]
y_data3 = [80.99, 80.99, 81.04, 81.03, 81.05, 81.09]
y_data4 = [29.97, 29.97, 29.97, 29.97, 29.98, 29.99]

y_data5 = [1.912, 1.912, 1.912, 1.911, 1.911, 1.911]
y_data6 = [19.32, 19.32, 19.32, 19.32, 19.32, 19.32]
y_data7 = [78.48, 78.51, 78.52, 78.57, 78.64, 78.71]
y_data8 = [28.99, 29.01, 29.01, 29.02, 29.04, 29.07]

y_data9 = [1.906, 1.906, 1.906, 1.906, 1.905, 1.904]
y_data10 = [19.32, 19.32, 19.32, 19.32, 19.32, 19.32]
y_data11 = [73.39, 74.43, 73.48, 73.57, 73.84, 74.06]
y_data12 = [27.03, 27.05, 27.06, 27.1, 27.18, 27.25]

plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
plt.plot(x_data, y_data1, 'o-')  # 빨간색
plt.plot(x_data, y_data5, 'o-')  # 빨간색
plt.plot(x_data, y_data9, 'o-')  # 빨간색
plt.xlabel('Interlayer Sheet Resistance(Ohm/sq)')
plt.ylabel('V_oc(V)')
plt.xscale('log') 
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(x_data, y_data2, 'o-')  # 파란색
plt.plot(x_data, y_data6, 'o-')  # 빨간색
plt.plot(x_data, y_data10, 'o-')  # 빨간색
plt.xlabel('Interlayer Sheet Resistance(Ohm/sq)')
plt.ylabel('Current Density(mA/cm²)')
plt.xscale('log') 
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(x_data, y_data3, 'o-')  # 초록색
plt.plot(x_data, y_data7, 'o-')  # 빨간색
plt.plot(x_data, y_data11, 'o-')  # 빨간색
plt.xlabel('Interlayer Sheet Resistance(Ohm/sq)')
plt.ylabel('Fill Factor(%)')
plt.xscale('log') 
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(x_data, y_data4, 'o-')  # 청록색
plt.plot(x_data, y_data8, 'o-')  # 빨간색
plt.plot(x_data, y_data12, 'o-')  # 빨간색
plt.xlabel('Interlayer Sheet Resistance(Ohm/sq)')
plt.ylabel('Power Conversion Efficiency(%)')
plt.xscale('log') 
plt.grid(True)

plt.tight_layout()  
plt.show()
